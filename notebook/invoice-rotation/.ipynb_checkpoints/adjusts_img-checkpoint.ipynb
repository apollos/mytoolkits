# %%
# coding: utf-8
'''
作用：通过二维码的角度、高宽，以及与抬头章的位置，对整张图片进行矫正，确保文字基本水平，并截取发票区域
效果：在200张样本集里面，随机正负90度旋转了若干张，程序可以以94%的准确率正确矫正角度并截取区域，水平角度误差在2度以内。
步骤：
0. 如果图片是竖着的（高大于宽），则左右旋转90度，看哪一个可以找到1个符合条件的二维码
1. 定位二维码和抬头章位置
2. 计算二维码角度，高宽
3. 矫正角度，高宽
4. 根据二维码和抬头章的位置计算发票位置并截取
'''
import cv2,os,random,glob,shutil,math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(16,16))
#====================================================
def img_rotate(img_in,angle): #用于左右旋转90度使用，高宽互换
    #img_in2 = img_in.copy()
    scale = 1.0
    h,w,channels = img_in.shape
    center = (h/2,w/2)
    M = cv2.getRotationMatrix2D(center,angle,scale)
    img_out = cv2.warpAffine(img_in,M,(h,w))
    return img_out
#====================================================
def split_color(img_in,obj): #从图像中分离出蓝色元素
    lower_blue=np.array([78,43,46])
    upper_blue=np.array([155,255,255])
    lower_red1 = np.array([0,43,46])
    upper_red1 = np.array([10,255,255])
    lower_red2 = np.array([156,43,46])
    upper_red2 = np.array([180,255,255])
    hsv = cv2.cvtColor(img_in, cv2.COLOR_BGR2HSV)
    if obj == '2dcode':
        mask = cv2.inRange(hsv, lower_blue,upper_blue)
    if obj == 'chop':
        mask1 = cv2.inRange(hsv, lower_red1,upper_red1)
        mask2 = cv2.inRange(hsv, lower_red2,upper_red2)
        mask = mask1 + mask2
    
    output = cv2.bitwise_and(img_in, img_in, mask=mask)
    output = output[:,:,(2,1,0)]
    return output
#====================================================
def find_boxes(img_in): #找到所有指定的颜色区域
    output = img_in.copy()
    
    #去噪，融合，二值化
    kernel = (5,5)     
    tmp = cv2.GaussianBlur(output,kernel,0) 
    kernel = np.ones((6,4),np.uint8)    
    tmp = cv2.morphologyEx(tmp, cv2.MORPH_OPEN, kernel)
    tmp = cv2.morphologyEx(tmp, cv2.MORPH_CLOSE, kernel)        
    #tmp = cv2.erode(tmp,None,iterations=1)
    #output = cv2.dilate(output,None,iterations=6)    
    tmp = cv2.cvtColor(tmp,cv2.COLOR_BGR2GRAY)
    _, thresh = cv2.threshold(tmp, 20, 255, cv2.THRESH_BINARY) #还是这种效果好
    #thresh = cv2.adaptiveThreshold(tmp,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,5,1)
    #thresh = cv2.adaptiveThreshold(tmp,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
    #_,thresh = cv2.threshold(tmp,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    
    #生成区域包围点
    thresh,cnts,hes = cv2.findContours(thresh,cv2.RETR_EXTERNAL,cv2.CHAIN_APPROX_SIMPLE)     
    cv2.drawContours(output,cnts,-1,(0,255,0),8)
    print 'Total found boxes:',len(cnts)
    return cnts,output 
#====================================================
def filte_boxes(img_in,cnts,obj): #过滤出对象矩形框
    #ojb: 2dcode or chop
    h,w,c = img_in.shape
    output = img_in.copy()
    #c = sorted(cnts, key = cv2.contourArea, reverse = True)[0] #面积最大的
    keep_cnts = []
    if obj == '2dcode':
        ratio = (0.73,1.3) #长宽比阈值
        x_limit,y_limit = w/2,h/2 #应位于图片上半部和左半部
        min_area,max_area = (min(h,w)/15)**2,(min(h,w)/8)**2 #面积阈值，按短边比例测算
    if obj == 'chop':
        ratio = (0.3,3.0)
        x_limit,y_limit = w,h/2 #应位于图片上半部
        min_area,max_area = (min(h,w)/15)**2,(min(h,w)/6)**2 
    for c in cnts:
        center,(edge1,edge2),angle = cv2.minAreaRect(c) #中点，长宽，转角;               
        if edge1*edge2>min_area and edge1*edge2<max_area: #按面积初滤
            #print edge1*edge2,min_area,max_area,float(edge1)/edge2,ratio[0],ratio[1]            
            if (float(edge1)/edge2 > ratio[0]) and (float(edge1)/edge2 < ratio[1]): #过滤出近似矩形
                if center[1] <=y_limit and center[0] <= x_limit: #位置过滤
                        keep_cnts.append(c)
                        #print edge1*edge2,min_area,max_area
        #box = np.int0(cv2.boxPoints(rect))#box(里面是ndarry数组，包含了4个顶点的位置)
    print '====>Keep %s: %i' %(obj,len(keep_cnts))  
    #cv2.drawContours(output,cnts,-1,(0,255,0),4)
    cv2.drawContours(output,keep_cnts,-1,(0,255,0),2)
    return keep_cnts,output
#====================================================
def revise_point(point,center,angle,ratio):  #计算从图中心点旋转角度后的坐标  
    #h,w,_ = img_in.shape 
    h,w = center[1]*2,center[0]*2
    anglePi = -angle*math.pi/180.0
    cosA = math.cos(anglePi)
    sinA = math.sin(anglePi)
    X1 = math.ceil(abs(0.5*h*cosA + 0.5*w*sinA))
    X2 = math.ceil(abs(0.5*h*cosA - 0.5*w*sinA))
    Y1 = math.ceil(abs(-0.5*h*sinA + 0.5*w*cosA))
    Y2 = math.ceil(abs(-0.5*h*sinA - 0.5*w*cosA))
    H = int(2*max(Y1,Y2))
    W = int(2*max(X1,X2))             
    j,i = point[1],point[0]
    #new_x = int(cosA*i-sinA*j-0.5*w*cosA+0.5*h*sinA+0.5*W)
    #new_y = int(sinA*i+cosA*j-0.5*w*sinA-0.5*h*cosA+0.5*H)
    new_x = cosA*i-sinA*j-0.5*w*cosA+0.5*h*sinA+0.5*w
    new_x = int(new_x)
    new_y = sinA*i+cosA*j-0.5*w*sinA-0.5*h*cosA+0.5*h
    new_y = int(new_y/ratio) #only adjust y axis
    return np.array([new_x,new_y])
#====================================================
def adjust_img(img_in,code_in,chop_in): #根据二维码和抬头章的位置，计算整张图的水平、垂直、转角
    h,w,_ = img_in.shape 
    img_center = (int(w/2.0),int(h/2.0))
    output = img_in.copy()
    if len(chop_in) ==1:
        c = chop_in[0]
        chop_center,(long_edge,short_edge),angle = cv2.minAreaRect(c)
        print 'Chop status(center,edge,angle):\n',chop_center,(long_edge,short_edge),angle
    c = code_in[0]
    box_center,(long_edge,short_edge),angle = cv2.minAreaRect(c)
    print '2Dcode status(center,edge,angle):\n',box_center,(long_edge,short_edge),angle

    
    #angle always between [0,-90]
    if angle<-45:angle = angle + 90 
    
    ###找到4个顶点位置，判断比较水平的和比较垂直的边，计算变形比
    box = np.int0(cv2.boxPoints(cv2.minAreaRect(c)))
    corners = box.reshape((-1,1,2))
    #cv2.polylines(output,corners,True,(255,0,0),16)
    revise_box = np.array([revise_point(b,box_center,angle,1) for b in box]) 

    for x,y in revise_box:#box:
        if x<box_center[0] and y<box_center[1]:
            left_up_pt = np.array([x,y])
            left_up_pt = revise_point(left_up_pt,box_center,-angle,1)
        if x<box_center[0] and y>box_center[1]:
            left_down_pt = np.array([x,y])
            left_down_pt = revise_point(left_down_pt,box_center,-angle,1)
        if x>box_center[0] and y<box_center[1]:
            right_up_pt = np.array([x,y])
            right_up_pt = revise_point(right_up_pt,box_center,-angle,1)
        if x>box_center[0] and y>box_center[1]:
            right_down_pt = np.array([x,y])
            right_down_pt = revise_point(right_down_pt,box_center,-angle,1)
    hor_dist = np.linalg.norm(left_down_pt-right_down_pt)
    ver_dist = np.linalg.norm(right_down_pt-right_up_pt)
    ratio = ver_dist*1.0/hor_dist 
    print left_up_pt,left_down_pt,right_up_pt,right_down_pt,hor_dist,ver_dist,ratio
      
    print "Adjust angle:",angle
    print "Adjust scale:",ratio
    
    #旋转矫正
    M_rotate = cv2.getRotationMatrix2D((w/2, h/2), angle, 1)
    output = cv2.warpAffine(output, M_rotate, (w, h))
    
    #长宽矫正
    output = cv2.resize(output,None,fy=1/ratio,fx=1)
    
    #计算新的二维码顶点坐标 left_up_pt,left_down_pt,right_up_pt,right_down_pt
    new_p_left_up = tuple(revise_point(left_up_pt,img_center,angle,ratio))
    new_p_left_down = tuple(revise_point(left_down_pt,img_center,angle,ratio))
    new_p_right_up = tuple(revise_point(right_up_pt,img_center,angle,ratio))
    new_p_right_down = tuple(revise_point(right_down_pt,img_center,angle,ratio))
    if len(chop_in) ==1: new_chop_center = np.array(revise_point(chop_center,img_center,angle,ratio))
    
    corners = np.array([new_p_left_up,new_p_left_down,new_p_right_down,new_p_right_up])
    corners = corners.reshape((-1,1,2))
    cv2.polylines(output,corners,True,(0,128,0),8)

    #画条水平线看看效果
    cv2.line(output,new_p_right_down,(new_p_right_down[0]+5000,new_p_right_down[1]),(0,255,0),2)
    print 'Revised rectangle:',new_p_left_up,new_p_left_down,new_p_right_down,new_p_right_up
        
    #截取票据主体: 以二维码的中心点和抬头章为基准，按比例测算
    base_point = (int((new_p_left_down[0]+new_p_right_down[0])*0.5),int((new_p_right_up[1]+new_p_right_down[1])*0.5))
    left_top_corner = (base_point[0]-int(hor_dist*1),base_point[1]-int(ver_dist*1))
    base_point = np.array(base_point)
    if len(chop_in) ==1:
        width = int(2.2*np.linalg.norm(base_point-new_chop_center))
        height = int(1.3*np.linalg.norm(base_point-new_chop_center))
        right_down_corner = (base_point[0]+width,base_point[1]+height)
    else:
        right_down_corner = (base_point[0]+int(hor_dist*11.9),base_point[1]+int(ver_dist*6.8))
    #cv2.rectangle(output,left_top_corner,right_down_corner,(255,0,0),4)
    output = output[left_top_corner[1]:right_down_corner[1],left_top_corner[0]:right_down_corner[0],:]
    return output
#====================================================
def analyze_img(img_in): #analyze img, rotate if not found 2dcode
    h,w,channel = img_in.shape 
    tmp = img_in.copy()
    if h>w:
        img_R90 = np.transpose(tmp,(1,0,2))
        img_R90 = cv2.flip(img_R90,1)
        tmp = img_R90

        detect_obj = 'chop'    
        split_img = split_color(tmp,detect_obj)
        all_conts,cnts_img = find_boxes(split_img)
        keeped_chop,filte_img = filte_boxes(tmp,all_conts,detect_obj)

        detect_obj = '2dcode'
        split_img = split_color(tmp,detect_obj)
        all_conts,cnts_img = find_boxes(split_img)
        keeped_2dcode,filte_img = filte_boxes(tmp,all_conts,detect_obj)   
        
        if len(keeped_2dcode) != 1:
            img_L90 = np.transpose(img_in,(1,0,2))
            img_L90 = cv2.flip(img_L90,0)
            tmp = img_L90

            detect_obj = 'chop'    
            split_img = split_color(tmp,detect_obj)
            all_conts,cnts_img = find_boxes(split_img)
            keeped_chop,filte_img = filte_boxes(tmp,all_conts,detect_obj)

            detect_obj = '2dcode'
            split_img = split_color(tmp,detect_obj)
            all_conts,cnts_img = find_boxes(split_img)
            keeped_2dcode,filte_img = filte_boxes(tmp,all_conts,detect_obj)
    else:
        detect_obj = 'chop'    
        split_img = split_color(tmp,detect_obj)
        all_conts,cnts_img = find_boxes(split_img)
        keeped_chop,filte_img = filte_boxes(tmp,all_conts,detect_obj)

        detect_obj = '2dcode'
        split_img = split_color(tmp,detect_obj)
        all_conts,cnts_img = find_boxes(split_img)
        keeped_2dcode,filte_img = filte_boxes(tmp,all_conts,detect_obj)
    return keeped_chop,keeped_2dcode,cnts_img,filte_img
#====================================================
if __name__=='__main__':
    print 'Starting...'
    img_dir = 'A1/'
    save_dir = 'save/' #save cropped make sure the dir exists
    err_dir = 'err/' #save len(box)!=1 images,make sure the dir exists
    
    #if os.path.exists(save_dir): shutil.rmtree(save_dir)
    #os.mkdir(save_dir)
    
    for f in glob.iglob(img_dir+'*/*.jpg'):
        print '===============>Processing:',f
        #f = 'A1/PP/PP0016-01e200357f3a0c16203fc5db159e3d6d.jpg'
        #f = 'PP0016-01e200357f3a0c16203fc5db159e3d6d.jpg' #horizon img
        #f = 'testrec.png'
        #f = 'wider.jpeg'
        img = cv2.imread(f) #BGR
        
        kpt_chop,kpt_2dcode,code_cnts_img,code_filte_img = analyze_img(img)
        
        if len(kpt_2dcode) == 1: # and len(kpt_chop) == 1: #found 1*2Dcode and 1*chop
            res_img = adjust_img(code_filte_img,kpt_2dcode,kpt_chop)
            save_f = save_dir+os.path.basename(f)
        else:
            save_f = err_dir+os.path.basename(f)
            res_img = code_filte_img
            print '--------->Error! Found %i 2dcode and %i chop!' %(len(kpt_2dcode),len(kpt_chop))
        #plt.imshow(res_img)
        #break
        
        cv2.imwrite(save_f,res_img)
        #plt.imshow(np.hstack([img,res])[:,:,(2,1,0)])
    print 'Done.'
# Out:
# Starting...
# ===============>Processing: A1/ZP/ZP0081-0d13d4cefea45ab8b850dbcdbead8a08.jpg
# Total found boxes: 26
# ====>Keep chop: 1
# Total found boxes: 1090
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1185.0, 428.0) (226.0, 150.0) -0.0
# 2Dcode status(center,edge,angle):
# (505.45697021484375, 461.30731201171875) (139.78848266601562, 140.66868591308594) -1.70981395245
# [432 392] [436 532] [572 387] [576 528] 140.05713120009278 141.05672617780408 1.007137051638472
# Adjust angle: -1.70981395245
# Adjust scale: 1.007137051638472
# Revised rectangle: (443, 369) (443, 508) (583, 508) (583, 368)
# ===============>Processing: A1/ZP/ZP0027-03b3dc663aa70bd6a35a35badb5d5fc4.jpg
# Total found boxes: 14
# ====>Keep chop: 1
# Total found boxes: 100
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (659.0, 225.0) (122.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (293.0, 234.5) (74.0, 71.0) -0.0
# [256 199] [256 270] [330 199] [330 270] 74.0 71.0 0.9594594594594594
# Adjust angle: -0.0
# Adjust scale: 0.9594594594594594
# Revised rectangle: (256, 207) (256, 281) (330, 281) (330, 207)
# ===============>Processing: A1/ZP/ZP0068-0b36ac62e0bed8886eaa076fd495423c.jpg
# Total found boxes: 2
# ====>Keep chop: 1
# Total found boxes: 104
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (662.0, 200.0) (120.0, 78.0) -0.0
# 2Dcode status(center,edge,angle):
# (282.0, 213.5) (66.0, 65.0) -0.0
# [249 181] [249 246] [315 181] [315 246] 66.0 65.0 0.9848484848484849
# Adjust angle: -0.0
# Adjust scale: 0.9848484848484849
# Revised rectangle: (249, 183) (249, 249) (315, 249) (315, 183)
# ===============>Processing: A1/ZP/ZP0052-088184225d61792d638418570c4b9784.jpg
# Total found boxes: 59
# ====>Keep chop: 1
# Total found boxes: 148
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (652.8619995117188, 198.84483337402344) (122.9903564453125, 82.04893493652344) -4.76364183426
# 2Dcode status(center,edge,angle):
# (301.17694091796875, 210.63182067871094) (74.74868774414062, 74.47297668457031) -1.9749339819
# [261 173] [264 248] [336 171] [338 245] 74.06078584514209 74.02702209328699 0.9995441075669154
# Adjust angle: -1.9749339819
# Adjust scale: 0.9995441075669154
# Revised rectangle: (269, 161) (269, 236) (343, 236) (344, 162)
# ===============>Processing: A1/ZP/ZP0030-040fd6477cfa4330d64f5a7d1ac41732.jpg
# Total found boxes: 202
# ====>Keep chop: 1
# Total found boxes: 258
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1214.0, 524.0) (244.0, 162.0) -0.0
# 2Dcode status(center,edge,angle):
# (513.4328002929688, 548.9693603515625) (146.37806701660156, 143.99423217773438) -0.511555850506
# [438 476] [439 620] [584 475] [586 619] 147.00340132119393 144.01388821915754 0.979663646724034
# Adjust angle: -0.511555850506
# Adjust scale: 0.979663646724034
# Revised rectangle: (441, 479) (440, 626) (587, 626) (587, 479)
# ===============>Processing: A1/ZP/ZP0096-0fcfeb6bfc59f0624a5a88c2a39803d7.jpg
# Total found boxes: 52
# ====>Keep chop: 1
# Total found boxes: 159
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (633.0, 214.0) (128.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (268.0243835449219, 223.6343994140625) (72.79196166992188, 73.16690063476562) -88.9769668579
# [231 185] [229 258] [304 186] [302 259] 73.00684899377592 73.02739212103907 1.0002813863020565
# Adjust angle: 1.02303314209
# Adjust scale: 1.0002813863020565
# Revised rectangle: (226, 191) (226, 264) (299, 263) (299, 190)
# ===============>Processing: A1/ZP/ZP0049-0825d0db282e4c0f89d726b7465527d5.jpg
# Total found boxes: 20
# ====>Keep chop: 1
# Total found boxes: 200
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (734.5, 231.0) (141.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (306.0, 231.5) (74.0, 85.0) -0.0
# [269 189] [269 274] [343 189] [343 274] 74.0 85.0 1.1486486486486487
# Adjust angle: -0.0
# Adjust scale: 1.1486486486486487
# Revised rectangle: (269, 164) (269, 238) (343, 238) (343, 164)
# ===============>Processing: A1/ZP/ZP0073-0bd8d322c6e6a97dc38062a5faa27706.jpg
# Total found boxes: 13
# ====>Keep chop: 1
# Total found boxes: 165
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (800.0, 300.0) (146.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (343.5, 311.5) (77.0, 77.0) -0.0
# [305 273] [305 350] [382 273] [382 350] 77.0 77.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (305, 273) (305, 350) (382, 350) (382, 273)
# ===============>Processing: A1/ZP/ZP0071-0ba64a8a8f0969eb83810c9640347778.jpg
# Total found boxes: 214
# ====>Keep chop: 1
# Total found boxes: 522
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1445.5, 473.0) (265.0, 178.0) -0.0
# 2Dcode status(center,edge,angle):
# (671.281982421875, 487.34051513671875) (156.1876678466797, 152.75836181640625) -1.0708245039
# [590 411] [593 564] [746 408] [749 561] 156.02884348735012 153.0294089382822 0.9807764097840596
# Adjust angle: -1.0708245039
# Adjust scale: 0.9807764097840596
# Revised rectangle: (599, 406) (600, 562) (756, 562) (755, 406)
# ===============>Processing: A1/ZP/ZP0062-0a4476201e8cc4f7c42ef84627561c00.jpg
# Total found boxes: 5
# ====>Keep chop: 1
# Total found boxes: 225
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (629.0, 217.0) (118.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (255.64285278320312, 232.2494354248047) (76.215576171875, 71.58299255371094) -1.81830310822
# [215 196] [217 268] [291 194] [293 265] 76.05918747922567 71.02816342831905 0.9338538286084009
# Adjust angle: -1.81830310822
# Adjust scale: 0.9338538286084009
# Revised rectangle: (222, 196) (221, 273) (297, 273) (298, 197)
# ===============>Processing: A1/ZP/ZP0093-0efae88b7ce4c975c68e052e3e5eb779.jpg
# Total found boxes: 220
# ====>Keep chop: 1
# Total found boxes: 325
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1204.0, 376.0) (242.0, 162.0) -0.0
# 2Dcode status(center,edge,angle):
# (484.5, 396.5) (145.0, 145.0) -0.0
# [412 324] [412 469] [557 324] [557 469] 145.0 145.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (412, 324) (412, 469) (557, 469) (557, 324)
# ===============>Processing: A1/ZP/ZP0064-0a792c8ff4f026df35b545c82ee4c0c3.jpg
# Total found boxes: 155
# ====>Keep chop: 1
# Total found boxes: 348
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1391.5, 385.5) (241.0, 161.0) -0.0
# 2Dcode status(center,edge,angle):
# (698.3209838867188, 414.51739501953125) (136.7755584716797, 143.7732696533203) -1.46880078316
# [627 343] [630 487] [763 339] [767 483] 137.05838172107534 144.05554484295286 1.0510524276882045
# Adjust angle: -1.46880078316
# Adjust scale: 1.0510524276882045
# Revised rectangle: (640, 311) (639, 448) (776, 447) (776, 310)
# ===============>Processing: A1/ZP/ZP0044-078f0441291356d5c915c8358333ba15.jpg
# Total found boxes: 6
# ====>Keep chop: 1
# Total found boxes: 293
# ====>Keep 2dcode: 0
# Total found boxes: 6
# ====>Keep chop: 1
# Total found boxes: 293
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1443.5, 458.0) (235.0, 154.0) -0.0
# 2Dcode status(center,edge,angle):
# (745.4999389648438, 487.5) (138.99996948242188, 140.99996948242188) 0.0
# [675 417] [675 558] [814 417] [814 558] 139.0 141.0 1.014388489208633
# Adjust angle: 0.0
# Adjust scale: 1.014388489208633
# Revised rectangle: (675, 411) (675, 550) (814, 550) (814, 411)
# ===============>Processing: A1/ZP/ZP0058-09e0459fa6fca77e50df88332eaa2a49.jpg
# Total found boxes: 15
# ====>Keep chop: 1
# Total found boxes: 405
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1380.0, 403.0) (252.0, 172.0) -0.0
# 2Dcode status(center,edge,angle):
# (597.22265625, 430.5825500488281) (141.1570281982422, 142.81399536132812) -0.818455576897
# [524 359] [525 501] [665 357] [667 499] 142.01408380861386 142.01408380861386 1.0
# Adjust angle: -0.818455576897
# Adjust scale: 1.0
# Revised rectangle: (532, 348) (531, 490) (673, 490) (673, 348)
# ===============>Processing: A1/ZP/ZP0005-00c52fed2584983f99af58f993c707bc.jpg
# Total found boxes: 125
# ====>Keep chop: 1
# Total found boxes: 303
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (986.5438842773438, 384.8019714355469) (158.56045532226562, 181.20217895507812) -89.2151794434
# 2Dcode status(center,edge,angle):
# (451.0, 382.5) (110.0, 145.0) -0.0
# [396 310] [396 455] [506 310] [506 455] 110.0 145.0 1.3181818181818181
# Adjust angle: -0.0
# Adjust scale: 1.3181818181818181
# Revised rectangle: (396, 235) (396, 345) (506, 345) (506, 235)
# ===============>Processing: A1/ZP/ZP0061-0a3376381eacbae5897eda32ac3d5108.jpg
# Total found boxes: 17
# ====>Keep chop: 1
# Total found boxes: 140
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (632.5, 246.5) (131.0, 85.0) -0.0
# 2Dcode status(center,edge,angle):
# (251.5, 250.5) (67.0, 67.0) -0.0
# [218 217] [218 284] [285 217] [285 284] 67.0 67.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (218, 217) (218, 284) (285, 284) (285, 217)
# ===============>Processing: A1/ZP/ZP0066-0aebdaba9c7db8afd7b0a878ccd01353.jpg
# Total found boxes: 128
# ====>Keep chop: 1
# Total found boxes: 169
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (771.8597412109375, 232.9683837890625) (148.2854766845703, 96.64828491210938) -1.3322198391
# 2Dcode status(center,edge,angle):
# (324.5, 247.5) (79.0, 77.0) -0.0
# [285 209] [285 286] [364 209] [364 286] 79.0 77.0 0.9746835443037974
# Adjust angle: -0.0
# Adjust scale: 0.9746835443037974
# Revised rectangle: (285, 214) (285, 293) (364, 293) (364, 214)
# ===============>Processing: A1/ZP/ZP0092-0ef4e66847fb8775ae2cd19810e91446.jpg
# Total found boxes: 262
# ====>Keep chop: 1
# Total found boxes: 411
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1253.54833984375, 398.77093505859375) (164.54244995117188, 245.1403045654297) -89.4153747559
# 2Dcode status(center,edge,angle):
# (507.0, 405.0) (148.0, 148.0) -0.0
# [433 331] [433 479] [581 331] [581 479] 148.0 148.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (433, 331) (433, 479) (581, 479) (581, 331)
# ===============>Processing: A1/ZP/ZP0016-02361021d7e2f585083a0f6124f18bcf.jpg
# Total found boxes: 11
# ====>Keep chop: 1
# Total found boxes: 84
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (600.5, 195.0) (121.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (240.0, 208.5) (72.0, 71.0) -0.0
# [204 173] [204 244] [276 173] [276 244] 72.0 71.0 0.9861111111111112
# Adjust angle: -0.0
# Adjust scale: 0.9861111111111112
# Revised rectangle: (204, 175) (204, 247) (276, 247) (276, 175)
# ===============>Processing: A1/ZP/ZP0095-0f6d35cb1de20a72471b4d0eaec7254f.jpg
# Total found boxes: 214
# ====>Keep chop: 1
# Total found boxes: 324
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1200.8092041015625, 494.1801452636719) (244.1282958984375, 166.53627014160156) -1.60226130486
# 2Dcode status(center,edge,angle):
# (476.6995849609375, 519.1804809570312) (145.79164123535156, 146.4871368408203) -1.24536430836
# [401 446] [404 592] [546 443] [550 589] 146.03081866510234 146.05478424207814 1.0001641131453953
# Adjust angle: -1.24536430836
# Adjust scale: 1.0001641131453953
# Revised rectangle: (409, 428) (409, 574) (555, 575) (554, 429)
# ===============>Processing: A1/ZP/ZP0037-0643ffc87bcaf9503f8aa358cbdbd3c6.jpg
# Total found boxes: 141
# ====>Keep chop: 0
# Total found boxes: 857
# ====>Keep 2dcode: 1
# 2Dcode status(center,edge,angle):
# (625.4337158203125, 619.41796875) (139.71681213378906, 141.2720947265625) -1.06091177464
# [553 549] [555 690] [692 546] [695 687] 140.03213916812098 141.0319112825179 1.0071395903850089
# Adjust angle: -1.06091177464
# Adjust scale: 1.0071395903850089
# Revised rectangle: (560, 531) (560, 671) (700, 671) (699, 531)
# ===============>Processing: A1/ZP/ZP0035-05a4d99de9db9ee854c1a2715f1c5cef.jpg
# Total found boxes: 202
# ====>Keep chop: 1
# Total found boxes: 329
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1209.4991455078125, 446.4383544921875) (241.07327270507812, 165.0119171142578) -0.784824550152
# 2Dcode status(center,edge,angle):
# (483.968017578125, 468.9359130859375) (145.748046875, 145.06883239746094) -1.31188774109
# [408 397] [411 542] [554 393] [557 538] 146.05478424207814 145.03103116229988 0.9929906227646645
# Adjust angle: -1.31188774109
# Adjust scale: 0.9929906227646645
# Revised rectangle: (418, 381) (417, 528) (563, 527) (564, 381)
# ===============>Processing: A1/ZP/ZP0011-01479f2380d1f743b36d220f99016d69.jpg
# Total found boxes: 20
# ====>Keep chop: 1
# Total found boxes: 136
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (631.5, 177.0) (123.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (275.0711669921875, 200.1373748779297) (73.4675521850586, 72.28961944580078) -2.93567347527
# [235 164] [239 237] [308 161] [312 233] 73.10950690573696 72.11102550927978 0.9863426599533142
# Adjust angle: -2.93567347527
# Adjust scale: 0.9863426599533142
# Revised rectangle: (248, 142) (249, 216) (322, 216) (322, 143)
# ===============>Processing: A1/ZP/ZP0045-079fab0770aa40588b872e7f1f31e68e.jpg
# Total found boxes: 7
# ====>Keep chop: 1
# Total found boxes: 148
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (775.435302734375, 206.6588134765625) (147.2572784423828, 96.7909927368164) -4.39870548248
# 2Dcode status(center,edge,angle):
# (330.0, 220.0) (90.0, 86.0) -0.0
# [285 177] [285 263] [375 177] [375 263] 90.0 86.0 0.9555555555555556
# Adjust angle: -0.0
# Adjust scale: 0.9555555555555556
# Revised rectangle: (285, 185) (285, 275) (375, 275) (375, 185)
# ===============>Processing: A1/ZP/ZP0033-0504a82c3e406e98a8764098a2736438.jpg
# Total found boxes: 22
# ====>Keep chop: 1
# Total found boxes: 97
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (594.3251953125, 188.45697021484375) (47.13825607299805, 104.3170166015625) -70.974395752
# 2Dcode status(center,edge,angle):
# (261.5, 218.0) (57.0, 68.0) -0.0
# [233 184] [233 252] [290 184] [290 252] 57.0 68.0 1.1929824561403508
# Adjust angle: -0.0
# Adjust scale: 1.1929824561403508
# Revised rectangle: (233, 154) (233, 211) (290, 211) (290, 154)
# ===============>Processing: A1/ZP/ZP0032-04ad73bcc0b4e9c520b6960368d9bf0b.jpg
# Total found boxes: 13
# ====>Keep chop: 1
# Total found boxes: 196
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (780.0, 242.0) (144.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (348.5, 261.5) (87.0, 89.0) -0.0
# [305 217] [305 306] [392 217] [392 306] 87.0 89.0 1.0229885057471264
# Adjust angle: -0.0
# Adjust scale: 1.0229885057471264
# Revised rectangle: (305, 212) (305, 299) (392, 299) (392, 212)
# ===============>Processing: A1/ZP/ZP0003-00948b9b5b1e095f21bd7705238b0271.jpg
# Total found boxes: 141
# ====>Keep chop: 1
# Total found boxes: 263
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1280.0, 391.0) (254.0, 166.0) -0.0
# 2Dcode status(center,edge,angle):
# (557.376953125, 377.4531555175781) (151.2437744140625, 159.07029724121094) -87.6140594482
# [480 297] [473 448] [638 304] [632 455] 159.15401345866212 151.11915828246265 0.9495152211270725
# Adjust angle: 2.38594055176
# Adjust scale: 0.9495152211270725
# Revised rectangle: (458, 343) (457, 502) (616, 503) (616, 344)
# ===============>Processing: A1/ZP/ZP0048-08070eb8537d183dd35e2d21164e6151.jpg
# Total found boxes: 236
# ====>Keep chop: 1
# Total found boxes: 349
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1344.5, 376.5) (253.0, 159.0) -0.0
# 2Dcode status(center,edge,angle):
# (625.0681762695312, 404.20916748046875) (147.6511688232422, 145.0717315673828) -0.830315411091
# [549 331] [551 476] [696 329] [698 474] 147.0136048126159 145.01379244747721 0.9863970931963224
# Adjust angle: -0.830315411091
# Adjust scale: 0.9863970931963224
# Revised rectangle: (556, 326) (555, 473) (702, 473) (703, 326)
# ===============>Processing: A1/ZP/ZP0039-06c1cb89e78806ea6975f8116654d7b7.jpg
# Total found boxes: 78
# ====>Keep chop: 1
# Total found boxes: 214
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (743.061767578125, 229.5325469970703) (97.79127502441406, 144.0728759765625) -88.8065032959
# 2Dcode status(center,edge,angle):
# (319.4999694824219, 244.5) (86.99998474121094, 86.99998474121094) -0.0
# [275 201] [275 288] [362 201] [362 288] 87.0 87.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (275, 201) (275, 288) (362, 288) (362, 201)
# ===============>Processing: A1/ZP/ZP0084-0d6ca7be98d5a6422049ba6c90627307.jpg
# Total found boxes: 19
# ====>Keep chop: 1
# Total found boxes: 339
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (917.0684814453125, 396.6019592285156) (108.35577392578125, 166.27499389648438) -88.3634185791
# 2Dcode status(center,edge,angle):
# (388.0793762207031, 390.25360107421875) (91.76888275146484, 93.90303802490234) -87.3974456787
# [342 341] [338 432] [436 345] [431 437] 93.13431161500041 92.13576938409967 0.989278470913829
# Adjust angle: 2.60255432129
# Adjust scale: 0.989278470913829
# Revised rectangle: (331, 367) (331, 459) (424, 460) (425, 367)
# ===============>Processing: A1/ZP/ZP0047-07e1b4def39f51076776b80dfaf6910e.jpg
# Total found boxes: 152
# ====>Keep chop: 1
# Total found boxes: 460
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1230.581787109375, 434.5453796386719) (157.4936981201172, 241.15789794921875) -89.274772644
# 2Dcode status(center,edge,angle):
# (516.528076171875, 435.7913818359375) (147.33224487304688, 144.309814453125) -88.6677780151
# [445 359] [441 506] [589 362] [585 510] 144.05554484295286 148.05404418657398 1.027756650033709
# Adjust angle: 1.33222198486
# Adjust scale: 1.027756650033709
# Revised rectangle: (434, 365) (433, 508) (577, 509) (578, 365)
# ===============>Processing: A1/ZP/ZP0060-0a32d15f2e607b0e07287863bf3ffd5d.jpg
# Total found boxes: 17
# ====>Keep chop: 1
# Total found boxes: 193
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (753.0, 274.0) (148.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (321.5, 278.5) (89.0, 87.0) -0.0
# [277 235] [277 322] [366 235] [366 322] 89.0 87.0 0.9775280898876404
# Adjust angle: -0.0
# Adjust scale: 0.9775280898876404
# Revised rectangle: (277, 240) (277, 329) (366, 329) (366, 240)
# ===============>Processing: A1/ZP/ZP0015-01f398214b00560a04e980ef4080da11.jpg
# Total found boxes: 19
# ====>Keep chop: 1
# Total found boxes: 236
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (805.5948486328125, 177.86651611328125) (76.93437957763672, 116.82516479492188) -88.2642974854
# 2Dcode status(center,edge,angle):
# (449.5, 176.49998474121094) (70.99998474121094, 62.99999237060547) -0.0
# [414 144] [414 207] [485 144] [485 207] 71.0 63.0 0.8873239436619719
# Adjust angle: -0.0
# Adjust scale: 0.8873239436619719
# Revised rectangle: (414, 162) (414, 233) (485, 233) (485, 162)
# ===============>Processing: A1/ZP/ZP0008-012df8b5b03e1635d1ab2c0a286228fc.jpg
# Total found boxes: 72
# ====>Keep chop: 1
# Total found boxes: 413
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1273.5, 469.0) (237.0, 162.0) -0.0
# 2Dcode status(center,edge,angle):
# (503.5920715332031, 506.9975891113281) (131.13877868652344, 129.40257263183594) -1.50743579865
# [435 443] [438 572] [566 439] [569 568] 131.06105447462264 129.0348790056394 0.9845402169461748
# Adjust angle: -1.50743579865
# Adjust scale: 0.9845402169461748
# Revised rectangle: (445, 430) (444, 561) (575, 560) (576, 429)
# ===============>Processing: A1/ZP/ZP0077-0c976939c8c15d30d8dcd37e50d17163.jpg
# Total found boxes: 62
# ====>Keep chop: 1
# Total found boxes: 114
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (613.4326171875, 229.92881774902344) (114.22753143310547, 59.24803161621094) -18.2458553314
# 2Dcode status(center,edge,angle):
# (248.4951934814453, 228.765380859375) (62.17072677612305, 62.640010833740234) -1.16913938522
# [215 197] [217 259] [277 195] [279 258] 62.00806399170998 63.0317380372777 1.0165087245056477
# Adjust angle: -1.16913938522
# Adjust scale: 1.0165087245056477
# Revised rectangle: (219, 186) (219, 247) (281, 248) (281, 186)
# ===============>Processing: A1/ZP/ZP0053-088ef0c00390b47d04386faabce5c3b0.jpg
# Total found boxes: 98
# ====>Keep chop: 1
# Total found boxes: 184
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (814.4583740234375, 238.03138732910156) (149.184326171875, 94.53693389892578) -3.31778097153
# 2Dcode status(center,edge,angle):
# (394.5, 247.0) (85.0, 86.0) -0.0
# [352 204] [352 290] [437 204] [437 290] 85.0 86.0 1.011764705882353
# Adjust angle: -0.0
# Adjust scale: 1.011764705882353
# Revised rectangle: (352, 201) (352, 286) (437, 286) (437, 201)
# ===============>Processing: A1/ZP/ZP0034-054a57f8f8a0a6a02f8363665249fc10.jpg
# Total found boxes: 586
# ====>Keep chop: 1
# Total found boxes: 566
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1967.221435546875, 711.1646118164062) (241.04934692382812, 370.0649719238281) -88.1438446045
# 2Dcode status(center,edge,angle):
# (883.4086303710938, 696.97705078125) (214.4403076171875, 219.8730926513672) -87.7760391235
# [776 584] [768 798] [996 593] [988 807] 220.18401395196702 214.1494805036893 0.9725932262748459
# Adjust angle: 2.22396087646
# Adjust scale: 0.9725932262748459
# Revised rectangle: (751, 638) (752, 858) (972, 859) (972, 639)
# ===============>Processing: A1/ZP/ZP0021-030d819427cd275cd3e46df115f6180d.jpg
# Total found boxes: 5
# ====>Keep chop: 1
# Total found boxes: 150
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (741.4288330078125, 288.4966125488281) (96.08160400390625, 143.40895080566406) -87.27368927
# 2Dcode status(center,edge,angle):
# (298.5, 299.4999694824219) (86.99998474121094, 84.99998474121094) 0.0
# [255 256] [255 341] [342 256] [342 341] 87.0 85.0 0.9770114942528736
# Adjust angle: 0.0
# Adjust scale: 0.9770114942528736
# Revised rectangle: (255, 262) (255, 349) (342, 349) (342, 262)
# ===============>Processing: A1/ZP/ZP0098-0fff7f48cb990c4eb909c437f287b00e.jpg
# Total found boxes: 213
# ====>Keep chop: 1
# Total found boxes: 308
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1242.5, 401.5) (241.0, 159.0) -0.0
# 2Dcode status(center,edge,angle):
# (516.093017578125, 406.6344299316406) (144.19107055664062, 144.2133026123047) -89.3634109497
# [443 332] [442 476] [587 334] [586 478] 144.01388821915754 144.00347218036097 0.9999276733728575
# Adjust angle: 0.636589050293
# Adjust scale: 0.9999276733728575
# Revised rectangle: (437, 340) (438, 484) (582, 484) (581, 340)
# ===============>Processing: A1/ZP/ZP0028-03b61762012d0d97542c83b95266ae61.jpg
# Total found boxes: 16
# ====>Keep chop: 2
# Total found boxes: 102
# ====>Keep 2dcode: 1
# 2Dcode status(center,edge,angle):
# (255.36769104003906, 196.1184539794922) (64.40069580078125, 63.624114990234375) -3.17983007431
# [220 165] [223 228] [284 161] [288 225] 65.06919393998976 64.1248781675256 0.9854875139019693
# Adjust angle: -3.17983007431
# Adjust scale: 0.9854875139019693
# Revised rectangle: (232, 149) (231, 213) (296, 214) (296, 149)
# ===============>Processing: A1/ZP/ZP0043-077b87d081f60ce370425f4cdfe1b1a0.jpg
# Total found boxes: 11
# ====>Keep chop: 0
# Total found boxes: 206
# ====>Keep 2dcode: 1
# 2Dcode status(center,edge,angle):
# (290.5014343261719, 249.9623565673828) (66.4809799194336, 67.14088439941406) -87.8389282227
# [257 214] [254 280] [324 217] [321 283] 67.06713054842886 66.06814663663572 0.9851047166678499
# Adjust angle: 2.16107177734
# Adjust scale: 0.9851047166678499
# Revised rectangle: (247, 231) (247, 298) (314, 298) (314, 231)
# ===============>Processing: A1/ZP/ZP0094-0f114e0f073abc4c9b84579426993ddc.jpg
# Total found boxes: 9
# ====>Keep chop: 1
# Total found boxes: 374
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1234.5, 359.5) (237.0, 159.0) -0.0
# 2Dcode status(center,edge,angle):
# (519.0, 365.5) (144.0, 143.0) -0.0
# [447 294] [447 437] [591 294] [591 437] 144.0 143.0 0.9930555555555556
# Adjust angle: -0.0
# Adjust scale: 0.9930555555555556
# Revised rectangle: (447, 296) (447, 440) (591, 440) (591, 296)
# ===============>Processing: A1/ZP/ZP0007-00ebac7552509e7ecc1795be34eeed85.jpg
# Total found boxes: 8
# ====>Keep chop: 0
# Total found boxes: 157
# ====>Keep 2dcode: 1
# 2Dcode status(center,edge,angle):
# (276.5, 199.5) (71.0, 73.0) -0.0
# [241 163] [241 236] [312 163] [312 236] 71.0 73.0 1.028169014084507
# Adjust angle: -0.0
# Adjust scale: 1.028169014084507
# Revised rectangle: (241, 158) (241, 229) (312, 229) (312, 158)
# ===============>Processing: A1/ZP/ZP0020-03043d142085837cc81f7894c2e719c3.jpg
# Total found boxes: 7
# ====>Keep chop: 1
# Total found boxes: 200
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (579.5, 176.0) (113.0, 76.0) -0.0
# 2Dcode status(center,edge,angle):
# (245.32244873046875, 190.86459350585938) (64.91268157958984, 70.42281341552734) -1.3322198391
# [211 155] [212 225] [275 153] [277 224] 65.00769185258002 71.02816342831905 1.0926116803130288
# Adjust angle: -1.3322198391
# Adjust scale: 1.0926116803130288
# Revised rectangle: (216, 134) (215, 198) (280, 199) (280, 134)
# ===============>Processing: A1/ZP/ZP0080-0cbd1085c901a87e765791b51aa1ae99.jpg
# Total found boxes: 6
# ====>Keep chop: 1
# Total found boxes: 129
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (694.5, 226.0) (125.0, 84.0) -0.0
# 2Dcode status(center,edge,angle):
# (308.0, 235.0) (76.0, 76.0) -0.0
# [270 197] [270 273] [346 197] [346 273] 76.0 76.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (270, 197) (270, 273) (346, 273) (346, 197)
# ===============>Processing: A1/ZP/ZP0014-01e2519299033b59c0fbefe3d4557127.jpg
# Total found boxes: 34
# ====>Keep chop: 1
# Total found boxes: 171
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (640.0, 241.0) (120.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (294.5, 249.5) (73.0, 73.0) -0.0
# [258 213] [258 286] [331 213] [331 286] 73.0 73.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (258, 213) (258, 286) (331, 286) (331, 213)
# ===============>Processing: A1/ZP/ZP0056-09bad1f1868dfffda3207f0da7200d56.jpg
# Total found boxes: 305
# ====>Keep chop: 1
# Total found boxes: 458
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1337.73388671875, 385.7127685546875) (158.31015014648438, 241.8404998779297) -86.8778686523
# 2Dcode status(center,edge,angle):
# (616.3310546875, 383.78118896484375) (133.52015686035156, 144.63690185546875) -87.3735961914
# [546 312] [540 446] [690 319] [684 452] 144.12494579357175 133.13526955694348 0.9237489653431084
# Adjust angle: 2.62640380859
# Adjust scale: 0.9237489653431084
# Revised rectangle: (523, 369) (523, 514) (667, 514) (667, 370)
# ===============>Processing: A1/ZP/ZP0029-040f7e93f17ea12e0460ae91699f148a.jpg
# Total found boxes: 7
# ====>Keep chop: 1
# Total found boxes: 69
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (630.0, 196.0) (136.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (277.0, 197.0) (82.0, 72.0) -0.0
# [236 161] [236 233] [318 161] [318 233] 82.0 72.0 0.8780487804878049
# Adjust angle: -0.0
# Adjust scale: 0.8780487804878049
# Revised rectangle: (236, 183) (236, 265) (318, 265) (318, 183)
# ===============>Processing: A1/ZP/ZP0067-0b134fa7b97c09d5753b4e6ed4fbcf86.jpg
# Total found boxes: 157
# ====>Keep chop: 1
# Total found boxes: 319
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (738.0450439453125, 255.72569274902344) (96.72298431396484, 148.2317657470703) -88.5436401367
# 2Dcode status(center,edge,angle):
# (291.6469421386719, 250.32586669921875) (86.7706298828125, 88.44927215576172) -87.7093887329
# [248 204] [244 290] [336 207] [333 294] 89.08984229416954 87.05170877128145 0.9771227171313392
# Adjust angle: 2.29061126709
# Adjust scale: 0.9771227171313392
# Revised rectangle: (236, 228) (236, 316) (325, 316) (324, 227)
# ===============>Processing: A1/ZP/ZP0057-09bc0c90932de2f409c19bfaeac09a3d.jpg
# Total found boxes: 32
# ====>Keep chop: 1
# Total found boxes: 147
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (578.1226806640625, 191.8207550048828) (121.79798126220703, 81.48823547363281) -2.4895529747
# 2Dcode status(center,edge,angle):
# (230.5, 194.5) (73.0, 73.0) -0.0
# [194 158] [194 231] [267 158] [267 231] 73.0 73.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (194, 158) (194, 231) (267, 231) (267, 158)
# ===============>Processing: A1/ZP/ZP0069-0b59f63820f58c7d7d5d1de5f5f16dd1.jpg
# Total found boxes: 39
# ====>Keep chop: 1
# Total found boxes: 160
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (636.9999389648438, 203.49996948242188) (123.99998474121094, 80.99998474121094) -0.0
# 2Dcode status(center,edge,angle):
# (272.2854309082031, 188.21905517578125) (76.6298828125, 74.30172729492188) -86.1859207153
# [236 146] [231 222] [310 151] [305 227] 74.16872656315464 76.16429609731846 1.0269058082379856
# Adjust angle: 3.81407928467
# Adjust scale: 1.0269058082379856
# Revised rectangle: (218, 165) (218, 239) (293, 239) (293, 165)
# ===============>Processing: A1/ZP/ZP0055-097a5720bc5fcf4f4a0c318e0b6e86ee.jpg
# Total found boxes: 135
# ====>Keep chop: 1
# Total found boxes: 331
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1225.2901611328125, 482.31817626953125) (238.95558166503906, 160.7968292236328) -5.49232387543
# 2Dcode status(center,edge,angle):
# (501.1398010253906, 493.5553283691406) (143.7036895751953, 144.6727294921875) -0.590657293797
# [427 420] [429 565] [571 419] [572 564] 143.0034964607509 145.00344823486094 1.0139853347897612
# Adjust angle: -0.590657293797
# Adjust scale: 1.0139853347897612
# Revised rectangle: (431, 406) (431, 549) (574, 550) (575, 407)
# ===============>Processing: A1/ZP/ZP0019-02e4bf6785681b25960aec6afd15243a.jpg
# Total found boxes: 101
# ====>Keep chop: 1
# Total found boxes: 236
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (754.5240478515625, 164.19296264648438) (95.82814025878906, 153.0437774658203) -89.4031906128
# 2Dcode status(center,edge,angle):
# (303.0, 173.0) (120.0, 96.0) -0.0
# [243 125] [243 221] [363 125] [363 221] 120.0 96.0 0.8
# Adjust angle: -0.0
# Adjust scale: 0.8
# Revised rectangle: (243, 156) (243, 276) (363, 276) (363, 156)
# ===============>Processing: A1/ZP/ZP0050-08507b38627ac46fc5dd585704501970.jpg
# Total found boxes: 233
# ====>Keep chop: 1
# Total found boxes: 427
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1215.326171875, 490.8634033203125) (241.471435546875, 159.93003845214844) -1.76782715321
# 2Dcode status(center,edge,angle):
# (504.2869873046875, 533.2486572265625) (145.27076721191406, 143.0130615234375) -2.1210963726
# [428 463] [433 606] [573 458] [578 601] 145.08618128546908 143.0873858870865 0.9862233923267317
# Adjust angle: -2.1210963726
# Adjust scale: 0.9862233923267317
# Revised rectangle: (442, 441) (441, 586) (586, 587) (587, 442)
# ===============>Processing: A1/ZP/ZP0040-07105e4be2b287fe17f93a0abeb57d9e.jpg
# Total found boxes: 226
# ====>Keep chop: 1
# Total found boxes: 411
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1203.0, 458.5) (244.0, 163.0) -0.0
# 2Dcode status(center,edge,angle):
# (459.0, 470.0) (130.0, 128.0) -0.0
# [394 406] [394 534] [524 406] [524 534] 130.0 128.0 0.9846153846153847
# Adjust angle: -0.0
# Adjust scale: 0.9846153846153847
# Revised rectangle: (394, 412) (394, 542) (524, 542) (524, 412)
# ===============>Processing: A1/ZP/ZP0022-034a18389d942875ecf5207fafb54a80.jpg
# Total found boxes: 284
# ====>Keep chop: 1
# Total found boxes: 435
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1238.407958984375, 359.1490478515625) (253.59715270996094, 164.96307373046875) -1.98863792419
# 2Dcode status(center,edge,angle):
# (524.617431640625, 393.6034851074219) (145.60769653320312, 144.4732666015625) -1.10170614719
# [449 321] [452 466] [595 318] [597 463] 145.03103116229988 145.01379244747721 0.9998811377490423
# Adjust angle: -1.10170614719
# Adjust scale: 0.9998811377490423
# Revised rectangle: (458, 307) (458, 452) (603, 451) (604, 306)
# ===============>Processing: A1/ZP/ZP0025-0382ac0b96c18b9b8208ddcada5434b5.jpg
# Total found boxes: 128
# ====>Keep chop: 1
# Total found boxes: 242
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (793.5429077148438, 260.8668518066406) (145.19151306152344, 96.44578552246094) -1.31691253185
# 2Dcode status(center,edge,angle):
# (364.4999694824219, 269.5) (90.99998474121094, 86.99998474121094) 0.0
# [318 226] [318 313] [409 226] [409 313] 91.0 87.0 0.9560439560439561
# Adjust angle: 0.0
# Adjust scale: 0.9560439560439561
# Revised rectangle: (318, 236) (318, 327) (409, 327) (409, 236)
# ===============>Processing: A1/ZP/ZP0059-09e6e044905bbc7c75b496a7c71fe7ea.jpg
# Total found boxes: 28
# ====>Keep chop: 1
# Total found boxes: 87
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (789.5, 289.0) (141.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (342.5, 303.5) (87.0, 85.0) -0.0
# [299 261] [299 346] [386 261] [386 346] 87.0 85.0 0.9770114942528736
# Adjust angle: -0.0
# Adjust scale: 0.9770114942528736
# Revised rectangle: (299, 267) (299, 354) (386, 354) (386, 267)
# ===============>Processing: A1/ZP/ZP0089-0e2f2db14465937e2ed43e26c1d93e57.jpg
# Total found boxes: 281
# ====>Keep chop: 1
# Total found boxes: 274
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1172.0, 439.0) (244.0, 162.0) -0.0
# 2Dcode status(center,edge,angle):
# (440.49993896484375, 459.5) (148.99996948242188, 146.99996948242188) -0.0
# [365 386] [365 533] [514 386] [514 533] 149.0 147.0 0.9865771812080537
# Adjust angle: -0.0
# Adjust scale: 0.9865771812080537
# Revised rectangle: (365, 391) (365, 540) (514, 540) (514, 391)
# ===============>Processing: A1/ZP/ZP0085-0d6f16815c4871f366e0b321ca09696e.jpg
# Total found boxes: 2
# ====>Keep chop: 1
# Total found boxes: 42
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (604.0, 213.0) (120.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (243.5, 212.5) (61.0, 69.0) -0.0
# [213 178] [213 247] [274 178] [274 247] 61.0 69.0 1.1311475409836065
# Adjust angle: -0.0
# Adjust scale: 1.1311475409836065
# Revised rectangle: (213, 157) (213, 218) (274, 218) (274, 157)
# ===============>Processing: A1/ZP/ZP0006-00ca3ceccea5a75e3ee5cecbe9b74476.jpg
# Total found boxes: 27
# ====>Keep chop: 0
# Total found boxes: 117
# ====>Keep 2dcode: 1
# 2Dcode status(center,edge,angle):
# (269.8741149902344, 232.92498779296875) (73.40605163574219, 72.67889404296875) -88.9583740234
# [233 194] [231 267] [305 195] [304 269] 73.02739212103907 74.00675644831355 1.0134109174493215
# Adjust angle: 1.04162597656
# Adjust scale: 1.0134109174493215
# Revised rectangle: (229, 197) (228, 269) (301, 270) (301, 197)
# ===============>Processing: A1/ZP/ZP0083-0d5e824f1210077970072cf98810d6f4.jpg
# Total found boxes: 62
# ====>Keep chop: 1
# Total found boxes: 386
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1285.5, 613.5) (237.0, 159.0) -0.0
# 2Dcode status(center,edge,angle):
# (537.0, 641.5) (132.0, 129.0) -0.0
# [471 577] [471 706] [603 577] [603 706] 132.0 129.0 0.9772727272727273
# Adjust angle: -0.0
# Adjust scale: 0.9772727272727273
# Revised rectangle: (471, 590) (471, 722) (603, 722) (603, 590)
# ===============>Processing: A1/ZP/ZP0099-100753f75139cb1038513b8b2d34f346.jpg
# Total found boxes: 16
# ====>Keep chop: 1
# Total found boxes: 135
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (871.0, 317.5) (162.0, 109.0) -0.0
# 2Dcode status(center,edge,angle):
# (372.1527404785156, 336.8245849609375) (98.41513061523438, 97.53874206542969) -1.56935477257
# [320 288] [323 385] [419 285] [421 383] 98.02040603874276 98.02040603874276 1.0
# Adjust angle: -1.56935477257
# Adjust scale: 1.0
# Revised rectangle: (328, 274) (328, 371) (426, 371) (427, 273)
# ===============>Processing: A1/ZP/ZP0074-0c35d2768cd504c3d7869e2ebef78842.jpg
# Total found boxes: 88
# ====>Keep chop: 1
# Total found boxes: 248
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (857.5, 230.0) (175.0, 94.0) -0.0
# 2Dcode status(center,edge,angle):
# (419.5, 229.0) (89.0, 104.0) -0.0
# [375 177] [375 281] [464 177] [464 281] 89.0 104.0 1.1685393258426966
# Adjust angle: -0.0
# Adjust scale: 1.1685393258426966
# Revised rectangle: (375, 151) (375, 240) (464, 240) (464, 151)
# ===============>Processing: A1/ZP/ZP0023-03585e203df715357f97f20177ed4b1e.jpg
# Total found boxes: 108
# ====>Keep chop: 1
# Total found boxes: 370
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1358.4710693359375, 512.710205078125) (143.3538055419922, 175.56634521484375) -24.3493556976
# 2Dcode status(center,edge,angle):
# (697.380859375, 517.0318603515625) (140.30186462402344, 143.82679748535156) -89.0289764404
# [625 444] [623 584] [769 447] [767 587] 144.03124660989366 140.0142849854971 0.9721104849194535
# Adjust angle: 0.97102355957
# Adjust scale: 0.9721104849194535
# Revised rectangle: (616, 468) (616, 612) (760, 613) (760, 469)
# ===============>Processing: A1/ZP/ZP0041-071f42f46c5f92a2f54f3d28c464c037.jpg
# Total found boxes: 170
# ====>Keep chop: 1
# Total found boxes: 358
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1179.97314453125, 370.6987609863281) (240.08615112304688, 164.81146240234375) -0.406346231699
# 2Dcode status(center,edge,angle):
# (462.48779296875, 401.407470703125) (145.6082305908203, 142.4542694091797) -1.181188941
# [387 330] [390 473] [532 327] [535 470] 145.03103116229988 143.0314650697531 0.9862128395797646
# Adjust angle: -1.181188941
# Adjust scale: 0.9862128395797646
# Revised rectangle: (397, 318) (397, 463) (542, 463) (542, 318)
# ===============>Processing: A1/ZP/ZP0002-003728de954214ee2bb9d0d16c04789f.jpg
# Total found boxes: 70
# ====>Keep chop: 1
# Total found boxes: 145
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (627.5, 191.0) (123.0, 82.0) -0.0
# 2Dcode status(center,edge,angle):
# (252.0, 203.5) (66.0, 65.0) -0.0
# [219 171] [219 236] [285 171] [285 236] 66.0 65.0 0.9848484848484849
# Adjust angle: -0.0
# Adjust scale: 0.9848484848484849
# Revised rectangle: (219, 173) (219, 239) (285, 239) (285, 173)
# ===============>Processing: A1/ZP/ZP0079-0cbcea3fc2234634778a37ffb661d91f.jpg
# Total found boxes: 89
# ====>Keep chop: 1
# Total found boxes: 194
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (621.677001953125, 191.74752807617188) (126.6822280883789, 80.86720275878906) -0.795723557472
# 2Dcode status(center,edge,angle):
# (247.09677124023438, 208.51583862304688) (73.28697204589844, 72.00646209716797) -1.00508606434
# [208 172] [210 244] [282 170] [283 242] 73.02739212103907 72.00694410957877 0.9860265034554573
# Adjust angle: -1.00508606434
# Adjust scale: 0.9860265034554573
# Revised rectangle: (212, 167) (213, 240) (286, 239) (286, 166)
# ===============>Processing: A1/ZP/ZP0024-037f533e96a8d0086051c50bff2a9909.jpg
# Total found boxes: 57
# ====>Keep chop: 1
# Total found boxes: 157
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (600.8903198242188, 210.2114715576172) (117.99897003173828, 78.71544647216797) -4.86451435089
# 2Dcode status(center,edge,angle):
# (245.5, 223.0) (73.0, 72.0) -0.0
# [209 187] [209 259] [282 187] [282 259] 73.0 72.0 0.9863013698630136
# Adjust angle: -0.0
# Adjust scale: 0.9863013698630136
# Revised rectangle: (209, 189) (209, 262) (282, 262) (282, 189)
# ===============>Processing: A1/ZP/ZP0087-0d91580323645b90498cf35c6099bcda.jpg
# Total found boxes: 130
# ====>Keep chop: 1
# Total found boxes: 213
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (727.6767578125, 242.57080078125) (93.24082946777344, 148.80911254882812) -89.0289764404
# 2Dcode status(center,edge,angle):
# (305.5, 248.0) (87.0, 88.0) -0.0
# [262 204] [262 292] [349 204] [349 292] 87.0 88.0 1.0114942528735633
# Adjust angle: -0.0
# Adjust scale: 1.0114942528735633
# Revised rectangle: (262, 201) (262, 288) (349, 288) (349, 201)
# ===============>Processing: A1/ZP/ZP0054-08d16d886f0917d926d46b20401f2fd8.jpg
# Total found boxes: 259
# ====>Keep chop: 1
# Total found boxes: 459
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1281.0, 404.5) (254.0, 163.0) -0.0
# 2Dcode status(center,edge,angle):
# (547.0, 413.5) (148.0, 145.0) -0.0
# [473 341] [473 486] [621 341] [621 486] 148.0 145.0 0.9797297297297297
# Adjust angle: -0.0
# Adjust scale: 0.9797297297297297
# Revised rectangle: (473, 348) (473, 496) (621, 496) (621, 348)
# ===============>Processing: A1/ZP/ZP0013-01b81573ad6583b194f02489f1e00cb3.jpg
# Total found boxes: 38
# ====>Keep chop: 1
# Total found boxes: 76
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (653.0, 205.0) (116.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (307.0, 205.0) (68.0, 68.0) -0.0
# [273 171] [273 239] [341 171] [341 239] 68.0 68.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (273, 171) (273, 239) (341, 239) (341, 171)
# ===============>Processing: A1/ZP/ZP0078-0cb00e6a8356e4054ae3aa9d771ebe30.jpg
# Total found boxes: 15
# ====>Keep chop: 1
# Total found boxes: 74
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (694.5, 251.5) (123.0, 83.0) -0.0
# 2Dcode status(center,edge,angle):
# (315.9837341308594, 261.4104309082031) (73.59540557861328, 73.07763671875) -88.9769668579
# [279 222] [277 296] [352 224] [350 297] 73.00684899377592 73.02739212103907 1.0002813863020565
# Adjust angle: 1.02303314209
# Adjust scale: 1.0002813863020565
# Revised rectangle: (273, 228) (273, 302) (346, 302) (346, 229)
# ===============>Processing: A1/ZP/ZP0100-104f8193f72a185a62f5af038c7f6774.jpg
# Total found boxes: 125
# ====>Keep chop: 1
# Total found boxes: 172
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (779.6853637695312, 218.18020629882812) (95.39102172851562, 181.3274688720703) -87.7974014282
# 2Dcode status(center,edge,angle):
# (358.0, 228.5) (88.0, 89.0) -0.0
# [314 184] [314 273] [402 184] [402 273] 88.0 89.0 1.0113636363636365
# Adjust angle: -0.0
# Adjust scale: 1.0113636363636365
# Revised rectangle: (314, 181) (314, 269) (402, 269) (402, 181)
# ===============>Processing: A1/ZP/ZP0086-0d7517409a3fb1f99f812c1e0424f480.jpg
# Total found boxes: 227
# ====>Keep chop: 1
# Total found boxes: 396
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1229.9766845703125, 438.2658996582031) (238.14332580566406, 161.6058349609375) -0.596809446812
# 2Dcode status(center,edge,angle):
# (502.0, 456.0) (144.0, 146.0) -0.0
# [430 383] [430 529] [574 383] [574 529] 144.0 146.0 1.0138888888888888
# Adjust angle: -0.0
# Adjust scale: 1.0138888888888888
# Revised rectangle: (430, 377) (430, 521) (574, 521) (574, 377)
# ===============>Processing: A1/ZP/ZP0017-02429480799cd03b413969ac628a1a44.jpg
# Total found boxes: 243
# ====>Keep chop: 1
# Total found boxes: 497
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1199.381591796875, 416.6686096191406) (257.2790222167969, 163.17970275878906) -1.77146983147
# 2Dcode status(center,edge,angle):
# (451.5, 448.5) (133.0, 131.0) -0.0
# [385 383] [385 514] [518 383] [518 514] 133.0 131.0 0.9849624060150376
# Adjust angle: -0.0
# Adjust scale: 0.9849624060150376
# Revised rectangle: (385, 388) (385, 521) (518, 521) (518, 388)
# ===============>Processing: A1/ZP/ZP0031-0483e628e4fa02605ebd695dd91a41a4.jpg
# Total found boxes: 7
# ====>Keep chop: 1
# Total found boxes: 75
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (592.0, 234.5) (118.0, 79.0) -0.0
# 2Dcode status(center,edge,angle):
# (228.5, 244.5) (71.0, 71.0) -0.0
# [193 209] [193 280] [264 209] [264 280] 71.0 71.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (193, 209) (193, 280) (264, 280) (264, 209)
# ===============>Processing: A1/ZP/ZP0070-0b695e2483f029de258cbc7d6c02043a.jpg
# Total found boxes: 200
# ====>Keep chop: 1
# Total found boxes: 240
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (959.0943603515625, 324.4440612792969) (123.26899719238281, 186.20545959472656) -88.6677780151
# 2Dcode status(center,edge,angle):
# (420.5, 334.0) (85.0, 98.0) -0.0
# [378 285] [378 383] [463 285] [463 383] 85.0 98.0 1.1529411764705881
# Adjust angle: -0.0
# Adjust scale: 1.1529411764705881
# Revised rectangle: (378, 247) (378, 332) (463, 332) (463, 247)
# ===============>Processing: A1/ZP/ZP0010-0144756187683c870c092c05e712c575.jpg
# Total found boxes: 154
# ====>Keep chop: 1
# Total found boxes: 281
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (757.5, 321.0) (169.0, 94.0) -0.0
# 2Dcode status(center,edge,angle):
# (301.127685546875, 327.10418701171875) (79.22715759277344, 81.65267944335938) -88.9390945435
# [260 285] [258 364] [341 287] [340 366] 82.02438661763951 79.00632886041473 0.9632053602388568
# Adjust angle: 1.06090545654
# Adjust scale: 0.9632053602388568
# Revised rectangle: (256, 304) (255, 386) (337, 387) (337, 305)
# ===============>Processing: A1/ZP/ZP0012-016f3cd0f405fbf4ba80a85e37c778f4.jpg
# Total found boxes: 149
# ====>Keep chop: 1
# Total found boxes: 349
# ====>Keep 2dcode: 0
# --------->Error! Found 0 2dcode and 1 chop!
# ===============>Processing: A1/ZP/ZP0097-0ff8e198ffa7f239b1ff4861ac297206.jpg
# Total found boxes: 13
# ====>Keep chop: 1
# Total found boxes: 85
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (397.1265563964844, 103.84007263183594) (34.582183837890625, 55.955902099609375) -36.1193389893
# 2Dcode status(center,edge,angle):
# (160.5, 119.0) (43.0, 44.0) -0.0
# [139  97] [139 141] [182  97] [182 141] 43.0 44.0 1.0232558139534884
# Adjust angle: -0.0
# Adjust scale: 1.0232558139534884
# Revised rectangle: (139, 94) (139, 137) (182, 137) (182, 94)
# ===============>Processing: A1/ZP/ZP0063-0a4deec34fa7fc05c653a126c590da74.jpg
# Total found boxes: 84
# ====>Keep chop: 0
# Total found boxes: 1026
# ====>Keep 2dcode: 0
# --------->Error! Found 0 2dcode and 0 chop!
# ===============>Processing: A1/ZP/ZP0042-0775912b804bbd5e2387a344dfd4a9b1.jpg
# Total found boxes: 270
# ====>Keep chop: 1
# Total found boxes: 407
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1198.8382568359375, 428.57470703125) (242.09243774414062, 161.39495849609375) -1.16913926601
# 2Dcode status(center,edge,angle):
# (489.5, 457.5) (145.0, 145.0) -0.0
# [417 385] [417 530] [562 385] [562 530] 145.0 145.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (417, 385) (417, 530) (562, 530) (562, 385)
# ===============>Processing: A1/ZP/ZP0051-085d9e47c811c76f3725544f77fea429.jpg
# Total found boxes: 237
# ====>Keep chop: 1
# Total found boxes: 323
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1278.0172119140625, 420.2930908203125) (163.6078338623047, 244.1289825439453) -89.4212799072
# 2Dcode status(center,edge,angle):
# (560.920166015625, 423.3675537109375) (148.81607055664062, 146.42295837402344) -89.0608062744
# [487 346] [485 495] [634 349] [631 497] 146.01369798755184 148.03040228277433 1.0138117472745223
# Adjust angle: 0.939193725586
# Adjust scale: 1.0138117472745223
# Revised rectangle: (479, 352) (479, 499) (625, 499) (626, 353)
# ===============>Processing: A1/ZP/ZP0090-0eb587100fe85e3873196bce027df24b.jpg
# Total found boxes: 8
# ====>Keep chop: 1
# Total found boxes: 91
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (734.0, 244.0) (120.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (370.5, 245.5) (71.0, 73.0) -0.0
# [335 209] [335 282] [406 209] [406 282] 71.0 73.0 1.028169014084507
# Adjust angle: -0.0
# Adjust scale: 1.028169014084507
# Revised rectangle: (335, 203) (335, 274) (406, 274) (406, 203)
# ===============>Processing: A1/ZP/ZP0065-0a7c55b2b0a4e9a38c6bc06a71f9f6a7.jpg
# Total found boxes: 1
# ====>Keep chop: 1
# Total found boxes: 61
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (638.0, 205.0) (120.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (271.0919189453125, 207.70782470703125) (68.48343658447266, 73.1495132446289) -89.0906219482
# [234 171] [232 240] [307 173] [306 241] 74.00675644831355 68.00735254367721 0.9189343758251811
# Adjust angle: 0.909378051758
# Adjust scale: 0.9189343758251811
# Revised rectangle: (230, 192) (229, 267) (303, 267) (303, 193)
# ===============>Processing: A1/ZP/ZP0046-07acdcbb1d05f8ddcd1a4d9a3ff7bec6.jpg
# Total found boxes: 236
# ====>Keep chop: 1
# Total found boxes: 446
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1268.533935546875, 454.56201171875) (159.46669006347656, 240.87521362304688) -88.9949111938
# 2Dcode status(center,edge,angle):
# (545.5, 467.5) (147.0, 143.0) -0.0
# [472 396] [472 539] [619 396] [619 539] 147.0 143.0 0.9727891156462585
# Adjust angle: -0.0
# Adjust scale: 0.9727891156462585
# Revised rectangle: (472, 407) (472, 554) (619, 554) (619, 407)
# ===============>Processing: A1/ZP/ZP0026-03a8afd2942ae9da84599086d4b66c27.jpg
# Total found boxes: 213
# ====>Keep chop: 1
# Total found boxes: 325
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1281.0, 283.0) (244.0, 162.0) -0.0
# 2Dcode status(center,edge,angle):
# (528.0, 295.0) (132.0, 128.0) -0.0
# [462 231] [462 359] [594 231] [594 359] 132.0 128.0 0.9696969696969697
# Adjust angle: -0.0
# Adjust scale: 0.9696969696969697
# Revised rectangle: (462, 238) (462, 370) (594, 370) (594, 238)
# ===============>Processing: A1/ZP/ZP0082-0d1921175b7aa88cc43b7994c95f30bf.jpg
# Total found boxes: 2
# ====>Keep chop: 1
# Total found boxes: 173
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (667.0, 295.0) (124.0, 84.0) -0.0
# 2Dcode status(center,edge,angle):
# (273.5, 303.9999694824219) (64.99998474121094, 67.99998474121094) 0.0
# [241 269] [241 337] [306 269] [306 337] 65.0 68.0 1.0461538461538462
# Adjust angle: 0.0
# Adjust scale: 1.0461538461538462
# Revised rectangle: (241, 257) (241, 322) (306, 322) (306, 257)
# ===============>Processing: A1/ZP/ZP0088-0ded58b18cfb2ee33e99893cf000370d.jpg
# Total found boxes: 49
# ====>Keep chop: 1
# Total found boxes: 462
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1260.957275390625, 361.38140869140625) (235.960205078125, 161.44386291503906) -8.53076553345
# 2Dcode status(center,edge,angle):
# (579.5, 380.5) (145.0, 145.0) -0.0
# ...
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1375.3594970703125, 471.11822509765625) (155.67709350585938, 248.66983032226562) -86.845161438
# 2Dcode status(center,edge,angle):
# (621.48193359375, 459.5332336425781) (152.81053161621094, 157.31639099121094) -88.0585174561
# [544 379] [539 532] [701 384] [696 537] 157.07959765672945 153.08167754502824 0.974548444410725
# Adjust angle: 1.94148254395
# Adjust scale: 0.974548444410725
# Revised rectangle: (527, 413) (527, 570) (684, 570) (684, 413)
# ===============>Processing: A1/PP/PP0114-10af2ccb8840a3363cb21ddcda610a49.jpg
# Total found boxes: 7
# ====>Keep chop: 1
# Total found boxes: 218
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (662.0, 227.5) (120.0, 81.0) -0.0
# 2Dcode status(center,edge,angle):
# (297.5, 237.0) (65.0, 66.0) -0.0
# [265 204] [265 270] [330 204] [330 270] 65.0 66.0 1.0153846153846153
# Adjust angle: -0.0
# Adjust scale: 1.0153846153846153
# Revised rectangle: (265, 200) (265, 265) (330, 265) (330, 200)
# ===============>Processing: A1/PP/PP0077-0b5fc2e24b92f8264321a8c66b2b7e09.jpg
# Total found boxes: 170
# ====>Keep chop: 1
# Total found boxes: 419
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1271.0, 536.0) (240.0, 162.0) -0.0
# 2Dcode status(center,edge,angle):
# (562.0, 562.0) (146.0, 144.0) -0.0
# [489 490] [489 634] [635 490] [635 634] 146.0 144.0 0.9863013698630136
# Adjust angle: -0.0
# Adjust scale: 0.9863013698630136
# Revised rectangle: (489, 496) (489, 642) (635, 642) (635, 496)
# ===============>Processing: A1/PP/PP0090-0cbeacf9782a30f14524d3ae6d2b511c.jpg
# Total found boxes: 5
# ====>Keep chop: 1
# Total found boxes: 1235
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1232.5, 714.0) (235.0, 158.0) -0.0
# 2Dcode status(center,edge,angle):
# (159.21986389160156, 418.1070556640625) (190.45518493652344, 193.1499786376953) -7.00679969788
# [ 51 332] [ 75 525] [240 309] [263 501] 189.52572384771415 193.3726971420733 1.0202978952738375
# Adjust angle: -7.00679969788
# Adjust scale: 1.0202978952738375
# Revised rectangle: (138, 181) (138, 371) (328, 370) (328, 181)
# ===============>Processing: A1/PP/PP0070-0aa3c5933e0ebb6b6abf1f894240f8ee.jpg
# Total found boxes: 14
# ====>Keep chop: 1
# Total found boxes: 179
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (785.0, 277.0) (146.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (353.83013916015625, 280.6727600097656) (89.0032730102539, 91.8546371459961) -88.9390945435
# [307 234] [306 323] [399 236] [397 325] 91.02197536858887 89.02246907382428 0.978032708182088
# Adjust angle: 1.06090545654
# Adjust scale: 0.978032708182088
# Revised rectangle: (302, 246) (302, 337) (393, 338) (394, 247)
# ===============>Processing: A1/PP/PP0050-07a5db6ccadc9d745ef69865c037e07f.jpg
# Total found boxes: 35
# ====>Keep chop: 1
# Total found boxes: 187
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (648.5, 180.5) (119.0, 81.0) -0.0
# 2Dcode status(center,edge,angle):
# (263.5, 188.5) (65.0, 67.0) -0.0
# [231 155] [231 222] [296 155] [296 222] 65.0 67.0 1.0307692307692307
# Adjust angle: -0.0
# Adjust scale: 1.0307692307692307
# Revised rectangle: (231, 150) (231, 215) (296, 215) (296, 150)
# ===============>Processing: A1/PP/PP0029-03b3f490e55a8ced1af6cb1c48c17b84.jpg
# Total found boxes: 137
# ====>Keep chop: 1
# Total found boxes: 477
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1956.0167236328125, 728.1982421875) (239.5938262939453, 358.2972412109375) -88.8065032959
# 2Dcode status(center,edge,angle):
# (833.778076171875, 750.619140625) (191.46380615234375, 197.67999267578125) -89.1987075806
# [735 652] [732 843] [932 655] [930 846] 198.022725968511 191.01047091717248 0.9645886348799502
# Adjust angle: 0.801292419434
# Adjust scale: 0.9645886348799502
# Revised rectangle: (726, 690) (726, 888) (924, 889) (923, 691)
# ===============>Processing: A1/PP/PP0002-002fe69b98be214cc2ce81aba7dd4fb9.jpg
# Total found boxes: 13
# ====>Keep chop: 1
# Total found boxes: 80
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (634.5, 233.5) (121.0, 81.0) -0.0
# 2Dcode status(center,edge,angle):
# (273.5, 248.0) (73.0, 72.0) -0.0
# [237 212] [237 284] [310 212] [310 284] 73.0 72.0 0.9863013698630136
# Adjust angle: -0.0
# Adjust scale: 0.9863013698630136
# Revised rectangle: (237, 214) (237, 287) (310, 287) (310, 214)
# ===============>Processing: A1/PP/PP0079-0bc5ef58ddd282070d2ef97d078dff56.jpg
# Total found boxes: 213
# ====>Keep chop: 1
# Total found boxes: 393
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1986.5, 605.5) (371.0, 239.0) -0.0
# 2Dcode status(center,edge,angle):
# (928.0, 647.4999389648438) (217.99996948242188, 216.99996948242188) -0.0
# [819 538] [819 755] [1037  538] [1037  755] 218.0 217.0 0.9954128440366973
# Adjust angle: -0.0
# Adjust scale: 0.9954128440366973
# Revised rectangle: (819, 540) (819, 758) (1037, 758) (1037, 540)
# ===============>Processing: A1/PP/PP0019-02484c7612e89b26bcec87148cfde60d.jpg
# Total found boxes: 19
# ====>Keep chop: 1
# Total found boxes: 263
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1502.5, 567.5) (257.0, 173.0) -0.0
# 2Dcode status(center,edge,angle):
# (712.3267211914062, 585.5933837890625) (138.91722106933594, 142.50331115722656) -89.5060806274
# [640 514] [639 653] [783 515] [781 654] 142.00352108310554 139.01438774457844 0.978950287177895
# Adjust angle: 0.493919372559
# Adjust scale: 0.978950287177895
# Revised rectangle: (636, 530) (636, 672) (778, 672) (779, 530)
# ===============>Processing: A1/PP/PP0073-0b0824dc51cd3dd8046ff58726d59ec3.jpg
# Total found boxes: 16
# ====>Keep chop: 1
# Total found boxes: 338
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (901.5, 285.5) (179.0, 121.0) -0.0
# 2Dcode status(center,edge,angle):
# (384.0, 302.0) (108.0, 108.0) -0.0
# [330 248] [330 356] [438 248] [438 356] 108.0 108.0 1.0
# Adjust angle: -0.0
# Adjust scale: 1.0
# Revised rectangle: (330, 248) (330, 356) (438, 356) (438, 248)
# ===============>Processing: A1/PP/PP0060-09ee8ce16e9780393fb3640099d45f5a.jpg
# Total found boxes: 15
# ====>Keep chop: 1
# Total found boxes: 77
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (701.5, 287.0) (119.0, 78.0) -0.0
# 2Dcode status(center,edge,angle):
# (331.4480285644531, 287.0989685058594) (71.16576385498047, 72.24554443359375) -88.8542404175
# [295 249] [293 320] [367 251] [365 322] 72.02777242147643 71.02816342831905 0.9861218949364686
# Adjust angle: 1.14575958252
# Adjust scale: 0.9861218949364686
# Revised rectangle: (291, 259) (290, 331) (362, 332) (363, 260)
# ===============>Processing: A1/PP/PP0033-03e9b9dac8731fc8e1a34f60caac3d10.jpg
# Total found boxes: 29
# ====>Keep chop: 1
# Total found boxes: 277
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1221.567626953125, 436.0096435546875) (160.28204345703125, 241.16873168945312) -89.0289764404
# 2Dcode status(center,edge,angle):
# (494.1373596191406, 459.25164794921875) (134.902099609375, 128.3816375732422) -0.806929409504
# [424 395] [426 523] [559 393] [561 521] 135.0148140020198 128.01562404644207 0.9481598370718564
# Adjust angle: -0.806929409504
# Adjust scale: 0.9481598370718564
# Revised rectangle: (430, 405) (430, 540) (565, 540) (565, 405)
# ===============>Processing: A1/PP/PP0066-0a88bb57ea2581358d93aaaf243d2325.jpg
# Total found boxes: 18
# ====>Keep chop: 1
# Total found boxes: 44
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (637.5, 201.0) (121.0, 80.0) -0.0
# 2Dcode status(center,edge,angle):
# (282.5, 217.99996948242188) (68.99998474121094, 69.99998474121094) -0.0
# [248 182] [248 252] [317 182] [317 252] 69.0 70.0 1.0144927536231885
# Adjust angle: -0.0
# Adjust scale: 1.0144927536231885
# Revised rectangle: (248, 179) (248, 248) (317, 248) (317, 179)
# ===============>Processing: A1/PP/PP0031-03cdbbf9b4c732da5a91a83befe3b0d7.jpg
# Total found boxes: 17
# ====>Keep chop: 1
# Total found boxes: 7
# ====>Keep 2dcode: 0
# --------->Error! Found 0 2dcode and 1 chop!
# ===============>Processing: A1/PP/PP0028-03a2b31563cea77c633d35a799331061.jpg
# Total found boxes: 173
# ====>Keep chop: 2
# Total found boxes: 517
# ====>Keep 2dcode: 1
# 2Dcode status(center,edge,angle):
# (443.22705078125, 496.1138610839844) (129.6540985107422, 132.78016662597656) -89.4437484741
# [376 429] [375 559] [509 430] [507 560] 132.00378782444085 130.01538370516005 0.9849367646788645
# Adjust angle: 0.556251525879
# Adjust scale: 0.9849367646788645
# Revised rectangle: (372, 443) (372, 575) (504, 575) (505, 443)
# ===============>Processing: A1/PP/PP0101-0dfac995ef0b18ebbd5491c20cc02b50.jpg
# Total found boxes: 14
# ====>Keep chop: 1
# Total found boxes: 130
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (640.5, 198.5) (119.0, 81.0) -0.0
# 2Dcode status(center,edge,angle):
# (314.6621398925781, 203.20361328125) (71.07134246826172, 92.243896484375) -88.7269668579
# [268 165] [266 236] [360 167] [358 238] 92.02173656261873 71.02816342831905 0.7718628889380497
# Adjust angle: 1.27303314209
# Adjust scale: 0.7718628889380497
# Revised rectangle: (262, 222) (262, 314) (354, 314) (354, 222)
# ===============>Processing: A1/PP/PP0053-088f90f6437f7100790a70686772e92f.jpg
# Total found boxes: 21
# ====>Keep chop: 1
# Total found boxes: 143
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (623.5, 158.5) (123.0, 81.0) -0.0
# 2Dcode status(center,edge,angle):
# (242.0, 163.5) (68.0, 65.0) -0.0
# [208 131] [208 196] [276 131] [276 196] 68.0 65.0 0.9558823529411765
# Adjust angle: -0.0
# Adjust scale: 0.9558823529411765
# Revised rectangle: (208, 137) (208, 205) (276, 205) (276, 137)
# ===============>Processing: A1/PP/PP0004-0097ef24564dc3ba15a57e7746a60135.jpg
# Total found boxes: 26
# ====>Keep chop: 0
# Total found boxes: 173
# ====>Keep 2dcode: 1
# 2Dcode status(center,edge,angle):
# (240.27967834472656, 168.88894653320312) (78.19490814208984, 76.09270477294922) -88.0250701904
# [202 127] [199 205] [278 130] [275 208] 76.05918747922567 78.05767098754612 1.0262753728320633
# Adjust angle: 1.97492980957
# Adjust scale: 1.0262753728320633
# Revised rectangle: (192, 134) (192, 210) (268, 210) (268, 134)
# ===============>Processing: A1/PP/PP0043-06ec4921d5f4f8d615bbb82c087ead37.jpg
# Total found boxes: 5
# ====>Keep chop: 1
# Total found boxes: 346
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1332.0, 495.5) (238.0, 163.0) -0.0
# 2Dcode status(center,edge,angle):
# (605.5800170898438, 525.0833740234375) (129.80552673339844, 129.06300354003906) -0.567266404629
# [539 460] [540 589] [668 458] [670 587] 130.01538370516005 129.0155029444136 0.9923095195948973
# Adjust angle: -0.567266404629
# Adjust scale: 0.9923095195948973
# Revised rectangle: (542, 457) (542, 587) (672, 586) (671, 456)
# ===============>Processing: A1/PP/PP0042-06c4eb811f68a73c7cfffbc2babb1d2d.jpg
# Total found boxes: 80
# ====>Keep chop: 1
# Total found boxes: 227
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (711.5, 158.0) (147.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (272.0162658691406, 175.70249938964844) (89.19454956054688, 88.55947875976562) -0.774220168591
# [225 131] [227 219] [315 129] [316 218] 89.00561780022652 89.00561780022652 1.0
# Adjust angle: -0.774220168591
# Adjust scale: 1.0
# Revised rectangle: (229, 124) (230, 212) (319, 212) (319, 123)
# ===============>Processing: A1/PP/PP0083-0c40b7afad48ac53b76fff86bfcb84e9.jpg
# Total found boxes: 21
# ====>Keep chop: 1
# Total found boxes: 71
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (550.1619873046875, 189.85935974121094) (50.61281204223633, 89.39424896240234) -43.0694122314
# 2Dcode status(center,edge,angle):
# (227.87753295898438, 195.52142333984375) (61.908409118652344, 59.66517639160156) -88.6028213501
# [197 162] [196 224] [257 164] [255 226] 59.033888572581766 62.03224967708329 1.0507905065548082
# Adjust angle: 1.3971786499
# Adjust scale: 1.0507905065548082
# Revised rectangle: (191, 162) (191, 221) (250, 222) (251, 163)
# ===============>Processing: A1/PP/PP0093-0d326007b397992d2ca800c974827d46.jpg
# Total found boxes: 16
# ====>Keep chop: 1
# Total found boxes: 59
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (546.30419921875, 190.30929565429688) (80.51695251464844, 82.44611358642578) -23.9624900818
# 2Dcode status(center,edge,angle):
# (227.99346923828125, 198.2640838623047) (57.394527435302734, 59.44929122924805) -1.59114027023
# [197 168] [199 227] [254 166] [256 226] 57.0087712549569 60.03332407921454 1.0530541661866577
# Adjust angle: -1.59114027023
# Adjust scale: 1.0530541661866577
# Revised rectangle: (203, 150) (203, 206) (260, 207) (260, 150)
# ===============>Processing: A1/PP/PP0017-02035468ac6e72b8fd1402339dd510ae.jpg
# Total found boxes: 5
# ====>Keep chop: 1
# Total found boxes: 235
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1281.5, 428.0) (239.0, 158.0) -0.0
# 2Dcode status(center,edge,angle):
# (535.5, 459.5) (115.0, 129.0) -0.0
# [478 395] [478 524] [593 395] [593 524] 115.0 129.0 1.1217391304347826
# Adjust angle: -0.0
# Adjust scale: 1.1217391304347826
# Revised rectangle: (478, 352) (478, 467) (593, 467) (593, 352)
# ===============>Processing: A1/PP/PP0058-09a10054bcbfe87e0195ed8a126cb3f7.jpg
# Total found boxes: 30
# ====>Keep chop: 1
# Total found boxes: 541
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1414.95068359375, 659.9638671875) (142.10107421875, 236.69520568847656) -83.1117401123
# 2Dcode status(center,edge,angle):
# (701.7383422851562, 686.072021484375) (143.33880615234375, 144.92616271972656) -0.716159999371
# [628 613] [629 758] [771 611] [773 756] 144.01388821915754 145.01379244747721 1.0069431097284036
# Adjust angle: -0.716159999371
# Adjust scale: 1.0069431097284036
# Revised rectangle: (632, 600) (631, 744) (775, 744) (775, 600)
# ===============>Processing: A1/PP/PP0056-091b9c81c2d1692e841ddb485dae14e1.jpg
# Total found boxes: 11
# ====>Keep chop: 1
# Total found boxes: 341
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (1268.5, 324.5) (239.0, 159.0) -0.0
# 2Dcode status(center,edge,angle):
# (654.7318725585938, 326.56781005859375) (144.25762939453125, 145.78387451171875) -89.4974136353
# [581 252] [580 397] [727 254] [725 398] 145.00344823486094 144.01388821915754 0.9931756104578933
# Adjust angle: 0.502586364746
# Adjust scale: 0.9931756104578933
# Revised rectangle: (575, 259) (576, 405) (721, 404) (721, 259)
# ===============>Processing: A1/PP/PP0048-0754b7d2c58e86a643a76de1731dfbf1.jpg
# Total found boxes: 15
# ====>Keep chop: 1
# Total found boxes: 123
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (731.5, 274.0) (147.0, 96.0) -0.0
# 2Dcode status(center,edge,angle):
# (319.97882080078125, 289.55914306640625) (87.16704559326172, 88.10812377929688) -0.84252423048
# [274 245] [276 333] [361 243] [363 331] 87.02298546935747 88.02272433866155 1.0114882161754393
# Adjust angle: -0.84252423048
# Adjust scale: 1.0114882161754393
# Revised rectangle: (277, 235) (278, 322) (365, 322) (364, 235)
# ===============>Processing: A1/PP/PP0027-037e0f1d7e5d9e9afefec16e8f71faae.jpg
# Total found boxes: 13
# ====>Keep chop: 1
# Total found boxes: 113
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (671.0266723632812, 211.2008819580078) (80.82177734375, 122.26543426513672) -88.0908508301
# 2Dcode status(center,edge,angle):
# (305.03717041015625, 229.6154327392578) (62.46531295776367, 65.26375579833984) -1.90915250778
# [271 197] [273 262] [334 194] [336 260] 63.0317380372777 66.03029607687671 1.0475721935166318
# Adjust angle: -1.90915250778
# Adjust scale: 1.0475721935166318
# Revised rectangle: (278, 177) (278, 239) (341, 240) (341, 177)
# ===============>Processing: A1/PP/PP0100-0dec3e7301242128a9bb98f41b5f4789.jpg
# Total found boxes: 34
# ====>Keep chop: 1
# Total found boxes: 147
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (749.0, 269.5) (146.0, 99.0) -0.0
# 2Dcode status(center,edge,angle):
# (305.0, 274.5) (80.0, 79.0) -0.0
# [265 235] [265 314] [345 235] [345 314] 80.0 79.0 0.9875
# Adjust angle: -0.0
# Adjust scale: 0.9875
# Revised rectangle: (265, 237) (265, 317) (345, 317) (345, 237)
# ===============>Processing: A1/PP/PP0113-108e1a5805e670f4a0a9aa3e1fd0b19f.jpg
# Total found boxes: 31
# ====>Keep chop: 1
# Total found boxes: 193
# ====>Keep 2dcode: 1
# Chop status(center,edge,angle):
# (629.5, 215.5) (119.0, 81.0) -0.0
# 2Dcode status(center,edge,angle):
# (264.0, 225.5) (62.0, 65.0) -0.0
# [233 193] [233 258] [295 193] [295 258] 62.0 65.0 1.0483870967741935
# Adjust angle: -0.0
# Adjust scale: 1.0483870967741935
# Revised rectangle: (233, 184) (233, 246) (295, 246) (295, 184)
# Done.
