# %%
# -*- coding: utf-8 -*-
import cv2,math,glob
import numpy as np
import matplotlib.pyplot as plt
import os
import shutil
# %matplotlib inline
import copy
from scipy.spatial import distance
import datetime

source_path = 'image/origin'
qrcode_path = 'image/qrcode'
target_path = 'image/output'
tmp_path = 'image/tmp'

def get_blue_color_center_by_kmeans(img, cluster_num):
    hsv = cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
    #hsv = img
    mean = np.mean(hsv)
    mean_v = np.mean(hsv[:,:,2])
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 10, 1.0)
    flags = cv2.KMEANS_RANDOM_CENTERS
    K= cluster_num
    Z = hsv.reshape((-1,np.shape(hsv)[-1]))
    # convert to np.float32
    Z = np.float32(Z)
    ret,label,center = cv2.kmeans(Z,K,None,criteria,5,cv2.KMEANS_RANDOM_CENTERS) #KMEANS_PP_CENTERS
    #print(center)
    max_ratio = 0
    max_ratio_color_idx = 0
    b_channel = 0
    g_channel = 1
    r_channel = 2
    for idx, color in enumerate(center):
        color_ratio = sum([float(color[b_channel])/float(color[g_channel])+0.00001, 
                           float(color[b_channel])/float(color[r_channel])+0.00001])
        if color_ratio > max_ratio:
            max_ratio = color_ratio
            max_ratio_color_idx = idx
    rst = np.array(center[max_ratio_color_idx], dtype=int)    
    return rst, mean, mean_v

def get_img_by_specified_blue_color(img, blue_color, hsv_mean, hsv_v_mean, model_g, model_r):    
    img_h,img_w,img_c = img.shape
    print("{} - {}".format(hsv_mean, hsv_v_mean))
    processed = np.full((img_h,img_w), 255, dtype=np.uint8)
    threshold_g = round(model_g.predict([[hsv_mean, hsv_v_mean, blue_color[0], blue_color[1], blue_color[2]]])[0])
    threshold_r = round(model_r.predict([[hsv_mean, hsv_v_mean, blue_color[0], blue_color[1], blue_color[2]]])[0])
    print("{} - {}".format(threshold_g, threshold_r))
    for row in range(img_h):
        for column in range(img_w):
            if img[row][column][0] <= img[row][column][1]+threshold_g or img[row][column][0] <= img[row][column][2]+threshold_r:
                processed[row][column] = 0

    output = cv2.bitwise_and(img, img, mask=processed)
    cv2.imwrite("t2.jpg",output)  

    return output

def init_predict_mode():
    from sklearn.multioutput import MultiOutputRegressor
    from sklearn.ensemble import GradientBoostingRegressor
    X_train = np.array([
        [135.7510472013719, 109.25225605127773, 139, 48, 40],
        [185.09503486644059, 155.8023853980109, 204, 135, 113], 
        [230.60940775681343, 219.56519541778977, 216, 194, 168],
        [230.60940775681343, 219.56519541778977, 217, 195, 169],
        [74.51976976976977, 55.34989401165872, 72, 43, 26],
        [74.51976976976977, 55.34989401165872, 72, 43, 25],
        [138.02507361059992, 113.39942951785056, 143, 123, 88], 
        [138.02507361059992, 113.39942951785056, 143, 123, 87],
        [147.66252587991718, 114.08598047914818, 165, 66, 50], 
        [148.35045933317494, 115.81777144214777, 154, 127, 89], 
        [148.35045933317494, 115.81777144214777, 154, 128, 90], 
        [148.35045933317494, 115.81777144214777, 155, 126, 88], 
        [187.56606274856387, 171.9030932390632, 168, 159, 135], 
        [96.20180167055167, 83.05893065268066, 95, 75, 61],
        [126.67964244521337, 92.01043468858131, 135,  93,  53],
        [136.3765201768933, 103.99979270315092, 152,  46,  37],
        [128.20973319715458, 109.20072031392786, 138, 104,  85],
        [182.78405112044817, 159.3824579831933, 212, 135, 133],
        [202.56029786400157, 185.39623750734862, 222, 159, 153],
        [176.70913293178316, 151.1599663818462, 186, 156, 128],
        [83.13366366366367, 53.38882882882883, 100, 47, 18],
        [115.19651513416542, 85.25867399519066, 116,  93,  56],
        [96.68841182127895, 75.24001173651523, 96, 63, 41],
        [223.23327652739417, 214.73126873126873, 210, 200, 190],
        [157.72678104575164, 122.33441176470588, 168,  83,  56],
    ])

    y_train = np.array([
        [4, 20],
        [4, 33],
        [40, 50],
        [40, 50],
        [-11, 3],
        [-11, 3],
        [-1, 30],
        [-1, 30],
        [40, 50],
        [-5, -2],
        [-5, -2],
        [-5, -2],
        [-15, -2],
        [-15, -2],
        [-5, 10],
        [2.0, 16],
        [5, 3],   
        [7.0, 20.0],
        [2, 2],
        [-3.0, -1.0],
        [-5.0, 10.0],
        [-11, 5],
        [-9.0, 4.0],
        [5.0, 8.0],
        [5.0, 8.0],
    ])
    max_depth = 20
    model_g = GradientBoostingRegressor(n_estimators=50, loss='huber', max_depth=max_depth)
    model_g.fit(X_train, y_train[:,0])
    model_r = GradientBoostingRegressor(n_estimators=50, loss='huber', max_depth=max_depth)
    model_r.fit(X_train, y_train[:,1])
    return model_g, model_r

# %%
source_file_lst = glob.glob(os.path.join(source_path, '*.jpg'))
model_g, model_r = init_predict_mode()
for source_file in source_file_lst:
    #if source_file.find("ZP0672") < 0:
    #    continue
    qrcode_file = "{}/{}_qrcode.jpg".format(qrcode_path, os.path.splitext(os.path.basename(source_file))[0])
    if not os.path.exists(qrcode_file):
        print("Missing qrcode jpg for image {}".format(source_file))
        continue
    print("Processing {}".format(os.path.basename(source_file)))
    img = cv2.imread(qrcode_file,cv2.IMREAD_COLOR)
    before_time = datetime.datetime.now()
    blue_color, hsv_mean, hsv_v_mean = get_blue_color_center_by_kmeans(img, 2)
    after_time = datetime.datetime.now()
    print("Kmeans Spend {}\n{}".format((after_time-before_time).seconds, blue_color))
    img = cv2.imread(source_file,cv2.IMREAD_COLOR)
    before_time = datetime.datetime.now()
    output = get_img_by_specified_blue_color(img, blue_color, hsv_mean, hsv_v_mean, model_g, model_r)
    after_time = datetime.datetime.now()
    print("Transfer Image Spend {}".format((after_time-before_time).seconds))
    
    tmp_file = "{}/{}_transfer.jpg".format(tmp_path, os.path.splitext(os.path.basename(source_file))[0])
    #print(tmp_file)
    cv2.imwrite(tmp_file, output)
    #output = cv2.imread(tmp_file,cv2.IMREAD_COLOR)
    before_time = datetime.datetime.now()
    
    
    # Same as before
    gray = cv2.cvtColor(output, cv2.COLOR_BGR2GRAY)
    gradX = cv2.Sobel(gray, ddepth = cv2.CV_32F, dx = 1, dy = 0, ksize = -1)
    gradY = cv2.Sobel(gray, ddepth = cv2.CV_32F, dx = 0, dy = 1, ksize = -1)
    gradient = cv2.subtract(gradX, gradY)
    gradient = cv2.convertScaleAbs(gradient)

    blurred = cv2.blur(gradient, (9, 9))
    (_, thresh) = cv2.threshold(blurred, 225, 255, cv2.THRESH_BINARY)

    closed = cv2.erode(blurred, None, iterations = 6)
    blurred = cv2.dilate(blurred, None, iterations = 6)

    (_, cnts, _) = cv2.findContours(blurred.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    img_h,img_w,img_c = img.shape
    min_area,max_area = 0,img_w/2.0*img_h/2
    boxes = []

    for (i, c) in enumerate(cnts):
        (x, y, w, h) = cv2.boundingRect(c)
        if w>0.2*h:
            if w*h>min_area and w*h<max_area: #scale and area filter
                if x>=50 and x <=img_w-100: #position filter
                    if y>=50 and y <=img_h-50:
                        boxes.append((x,y,w,h))
                        #cv2.rectangle(im_original,(x,y),(x+w,y+h),(0,0,255),2)
                        
    result = 255*np.ones((img_h,img_w,img_c),img.dtype)
    for x,y,w,h in boxes:
        result[y:y+h,x:x+w,:] = img[y:y+h,x:x+w,:]
    after_time = datetime.datetime.now()
    print("Rest Part Image Spend {}".format((after_time-before_time).seconds))
    output_file = "{}/{}_transfer.jpg".format(target_path, os.path.splitext(os.path.basename(source_file))[0])
    cv2.imwrite(output_file,result)
    #break
# Out:
# Processing ZP0521-501b24d980bc0976addcc4b2400bf7e8.jpg
# Kmeans Spend 0
# [157  90  66]
# 128.3421056428458 - 97.32125697961304
# -2.0 - 15.0
# Transfer Image Spend 20
# Rest Part Image Spend 0
# Processing ZP0524-50f27fa2d603fcc63a8755cc63dc7f05.jpg
# Kmeans Spend 0
# [179 107  54]
# 163.26735019903626 - 117.83591294783156
# 5.0 - 2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0693-6b1107e6ceb8b2022229c5ce83f8e9d0.jpg
# Kmeans Spend 0
# [116  92  55]
# 115.19651513416542 - 85.25867399519066
# -11.0 - 5.0
# Transfer Image Spend 20
# Rest Part Image Spend 0
# Processing ZP0690-6a160f93235345faf88a869c221d85ba.jpg
# Kmeans Spend 0
# [186 156 129]
# 176.70913293178316 - 151.1599663818462
# -3.0 - -1.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0652-64de8aac6a90ae384c4c40c7028ee016.jpg
# Kmeans Spend 0
# [224 156  87]
# 200.3206252610226 - 163.35833184177554
# 2.0 - 18.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0570-58b382037563e5be8db5ebef9f94400b.jpg
# Kmeans Spend 0
# [216 154 141]
# 203.62780660200016 - 185.76656891495603
# 5.0 - 11.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0655-65224b674bbe86fa1e88672642a7a818.jpg
# Kmeans Spend 0
# [183 100  57]
# 181.74707683543403 - 151.73518478957487
# 5.0 - 8.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0576-5931869b30860c5130f5accf6635a5db.jpg
# Kmeans Spend 0
# [167 102  77]
# 176.26901629072682 - 148.2031484962406
# 5.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0500-4c5864367e0bb5eccf244bc485596ffe.jpg
# Kmeans Spend 0
# [135  93  53]
# 126.67964244521337 - 92.01043468858131
# -5.0 - 10.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0552-56e017e371ed43364b8bce4355169c68.jpg
# Kmeans Spend 0
# [185  98  75]
# 190.4855202879581 - 169.73515215968587
# -3.0 - 5.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0567-58918d56a80c2ad39fcc49add22b5279.jpg
# Kmeans Spend 0
# [151  51  45]
# 153.6273175689074 - 129.12169095776324
# 24.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0544-53f9d912a14af8a3cf1a3ca3e4a6ee3f.jpg
# Kmeans Spend 0
# [123 112  88]
# 125.06232085067036 - 107.35913083680074
# -5.0 - 3.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0554-573bb6947cec556a63fbb5982e32fe52.jpg
# Kmeans Spend 0
# [155  40  31]
# 123.45741505968779 - 88.0396497441952
# -3.0 - 13.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0501-4c8a0dbafe08782ffa6c2a52f37dc4ea.jpg
# Kmeans Spend 0
# [215 151 140]
# 201.4670495067846 - 183.82063631732507
# 5.0 - 11.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0509-4d5641fb63c67b6477f6da18a0687a21.jpg
# Kmeans Spend 0
# [142  36  29]
# 127.36647619047619 - 96.0272
# -2.0 - 14.0
# Transfer Image Spend 22
# Rest Part Image Spend 0
# Processing ZP0692-6a617c038d6e00e001a6c080fc12be33.jpg
# Kmeans Spend 0
# [155  42  36]
# 132.822477827051 - 100.67572062084257
# 3.0 - 16.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0531-51d4c6762da5d47dcec009af5915c485.jpg
# Kmeans Spend 0
# [211 112 112]
# 186.25661375661375 - 167.24660493827162
# 4.0 - 24.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0636-61d5c851ede2fe11db75027a8fa356ff.jpg
# Kmeans Spend 0
# [89 65 44]
# 104.14061770717655 - 85.28197576167254
# -15.0 - 2.0
# Transfer Image Spend 21
# Rest Part Image Spend 0
# Processing ZP0658-65b14941487532fe9cb0a66e0e8bb2ec.jpg
# Kmeans Spend 0
# [139  48  40]
# 135.7510472013719 - 109.25225605127773
# 4.0 - 20.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0558-57706f5b7bf25af8c93038ce6c2a9ec3.jpg
# Kmeans Spend 0
# [79 52 30]
# 83.35421172795002 - 63.698044340302815
# -11.0 - 3.0
# Transfer Image Spend 21
# Rest Part Image Spend 0
# Processing ZP0651-648f1335c7f41e9a75c703c43d265fe9.jpg
# Kmeans Spend 0
# [102  75  49]
# 96.74535211267606 - 76.53854460093896
# -5.0 - 10.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0599-5c444a16438327a604a3d5f65fbc999c.jpg
# Kmeans Spend 0
# [154 120  98]
# 157.4035939643347 - 136.0259670781893
# -3.0 - -2.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0600-5c77ac836d42a41340f3008ebe1f03c3.jpg
# Kmeans Spend 0
# [169  78  41]
# 160.5236344537815 - 124.31431436210848
# 15.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0632-616bf5393735ebf5365e9bf4f9c4786c.jpg
# Kmeans Spend 0
# [237 173 172]
# 214.36241543400985 - 199.69195046439629
# 2.0 - 5.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0585-5ac39f7e70a2c2264290769a9f570820.jpg
# Kmeans Spend 0
# [178  66  41]
# 167.69907882937963 - 136.41076057715824
# 35.0 - 8.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0548-54eed720d034cf873edcb0d4a1bc35ce.jpg
# Kmeans Spend 0
# [140 118  90]
# 135.9948275862069 - 115.80436105476673
# -2.0 - 10.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0586-5af7fd20b450e018bc2c707ddd0ffa21.jpg
# Kmeans Spend 0
# [237 189 186]
# 221.1272770511296 - 208.67086801426873
# 2.0 - 6.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0563-581192e8181788256ae22e698096e885.jpg
# Kmeans Spend 0
# [82 52 29]
# 79.25847701149425 - 56.24846743295019
# -11.0 - 3.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0550-562fa87243567554eee7bdd54edcfbcc.jpg
# Kmeans Spend 0
# [179  94  44]
# 168.73563012677107 - 129.80398210290826
# 15.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0627-608bb8f6cd3d2e3ca4c9d50af48d1ded.jpg
# Kmeans Spend 0
# [95 47 25]
# 79.50352733686067 - 50.73139329805996
# -11.0 - 3.0
# Transfer Image Spend 19
# Rest Part Image Spend 0
# Processing ZP0577-599005abd50c9deb7a067768e161fec5.jpg
# Kmeans Spend 0
# [161  50  35]
# 152.59414316367958 - 119.92914370397814
# 34.0 - 8.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0594-5bfa619c1c79c1aa4146813a237540de.jpg
# Kmeans Spend 0
# [161  65  51]
# 164.6912409088856 - 138.3453381216967
# 40.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0653-6509ca24e1311b03e8268a725786670d.jpg
# Kmeans Spend 0
# [230 128 128]
# 183.3921674690323 - 156.63758316654946
# 3.0 - 26.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0645-63a30462900cf894fc299b0146a6e69b.jpg
# Kmeans Spend 0
# [127  66  34]
# 110.28671492942107 - 76.1613812544045
# -5.0 - 10.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0667-667eed19a043416d56d35206bc8df45b.jpg
# Kmeans Spend 0
# [160 160 148]
# 167.9106407995297 - 160.35390946502056
# -10.0 - -2.0
# Transfer Image Spend 22
# Rest Part Image Spend 0
# Processing ZP0571-58b457ff568d5f390496cba800026355.jpg
# Kmeans Spend 0
# [203 135 113]
# 185.09503486644059 - 155.8023853980109
# 4.0 - 33.0
# Transfer Image Spend 19
# Rest Part Image Spend 0
# Processing ZP0606-5d36eadf8e8388f5e01f64ef12cc4e97.jpg
# Kmeans Spend 0
# [139  71  53]
# 155.34030784030784 - 128.65023248356582
# 30.0 - 8.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0568-589ec12cfd89bfacd281c7f478f041af.jpg
# Kmeans Spend 0
# [182 138 113]
# 196.71712670116926 - 177.11261261261262
# -8.0 - -1.0
# Transfer Image Spend 26
# Rest Part Image Spend 0
# Processing ZP0559-57a7600afdea333b73083212beafcae4.jpg
# Kmeans Spend 0
# [89 60 33]
# 88.12813740412452 - 62.87639896141105
# -14.0 - 4.0
# Transfer Image Spend 24
# Rest Part Image Spend 0
# Processing ZP0612-5e690f926efde726af562e900687fb5a.jpg
# Kmeans Spend 0
# [136 102  83]
# 134.9793695887446 - 117.26704545454545
# -0.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0502-4cacc88305471619f8d4b6f603d6ab38.jpg
# Kmeans Spend 0
# [216 179 124]
# 213.3253992384427 - 187.3277591973244
# 6.0 - 12.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0656-65345cdf2ff9868d1a6b4fcc9c379e30.jpg
# Kmeans Spend 0
# [237 187 184]
# 219.08818990559186 - 205.2479121278141
# 2.0 - 6.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0634-61ae88164718cbea7c9137c0c8de6283.jpg
# Kmeans Spend 0
# [164 108  88]
# 184.37765957446808 - 163.68476220275343
# -6.0 - -2.0
# Transfer Image Spend 26
# Rest Part Image Spend 0
# Processing ZP0665-665e9c84874c1e8130c23c775ea95eb2.jpg
# Kmeans Spend 0
# [196 110  88]
# 160.77640901771338 - 128.65024154589372
# 6.0 - 31.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0592-5b70731770a0677f71864fc54cbf99d2.jpg
# Kmeans Spend 0
# [152  32  25]
# 136.14195665445666 - 103.59748168498169
# 2.0 - 16.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0628-60bffdb4bd4efb405914e273f5e932cd.jpg
# Kmeans Spend 0
# [138 120  94]
# 154.32003213359147 - 138.0981391489866
# -2.0 - 1.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0647-63edfaa0cf6b0fe5fa8dcc9fd58a7ec5.jpg
# Kmeans Spend 0
# [191 194 183]
# 187.64349376114083 - 182.13850267379678
# -15.0 - -1.0
# Transfer Image Spend 25
# Rest Part Image Spend 0
# Processing ZP0669-670279454ccee529d0c26d76f1ad9093.jpg
# Kmeans Spend 0
# [231 147 100]
# 195.47537678087838 - 158.09404803956198
# 2.0 - 22.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0573-58f33c022428cdeb83a87f2b30f521dc.jpg
# Kmeans Spend 0
# [150  74  57]
# 160.0592959575429 - 133.02612635501356
# 20.0 - 8.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0662-6635cdb8c56e144722d2ccf90b3f453f.jpg
# Kmeans Spend 0
# [137  62  49]
# 149.4449537037037 - 125.07472222222222
# 30.0 - 9.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0543-53dc3981188cee44b7f2cbb9e02c5513.jpg
# Kmeans Spend 0
# [180  68  42]
# 165.04519036519036 - 132.19016317016317
# 35.0 - 8.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0650-643c893ebc1d1621d139be905e8c4681.jpg
# Kmeans Spend 0
# [217 194 168]
# 230.60940775681343 - 219.56519541778977
# 40.0 - 50.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0639-62a187078459f1c9f787471aec2453b7.jpg
# Kmeans Spend 0
# [179  95  54]
# 157.48147467320263 - 115.278125
# 5.0 - 8.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0536-528a711306df10391f07244da6e20f21.jpg
# Kmeans Spend 0
# [149 124  95]
# 151.60623007113074 - 127.71415256315919
# -4.0 - -2.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0668-66eebd0081f92748b0081f0a4d214cca.jpg
# Kmeans Spend 0
# [90 31 18]
# 84.38974163274537 - 61.915917571234736
# -11.0 - 3.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0699-6cb3417cc48927e7becfb1be0cfa996e.jpg
# Kmeans Spend 0
# [168  84  56]
# 157.72678104575164 - 122.33441176470588
# 5.0 - 8.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0678-6824756b74378181a9a28f2c51199a17.jpg
# Kmeans Spend 0
# [222 163 158]
# 206.102828499821 - 191.11020408163265
# 2.0 - 2.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0545-542f9e728f0bd411834e74033a974141.jpg
# Kmeans Spend 0
# [111  76  59]
# 98.31919560569196 - 79.02079186020792
# -11.0 - 5.0
# Transfer Image Spend 26
# Rest Part Image Spend 0
# Processing ZP0611-5e04570a7db58ba0eae0303d7fa769ba.jpg
# Kmeans Spend 0
# [227 173 146]
# 205.94363215084692 - 180.15635985938
# 2.0 - 2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0635-61cf8c5ff18918b95afdc39610ee42f6.jpg
# Kmeans Spend 0
# [126  89  60]
# 110.74319486659913 - 84.9935663627153
# -11.0 - 5.0
# Transfer Image Spend 24
# Rest Part Image Spend 0
# Processing ZP0578-59a9a03ba4f8304c1a1ed902f289a2ed.jpg
# Kmeans Spend 0
# [144  48  50]
# 149.27641379310344 - 130.12993103448275
# 29.0 - 8.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0572-58bb87d97c6ae1486d1599fd3cf75fff.jpg
# Kmeans Spend 0
# [208 175 172]
# 216.22229251012146 - 207.81983805668017
# 5.0 - 8.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0526-513b75365f12bc66d660efb97106a082.jpg
# Kmeans Spend 0
# [222 159 153]
# 202.56029786400157 - 185.39623750734862
# 2.0 - 2.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0686-69b2d3d96e9533c2756dfb59b982bf09.jpg
# Kmeans Spend 0
# [73 44 26]
# 74.51976976976977 - 55.34989401165872
# -11.0 - 3.0
# Transfer Image Spend 21
# Rest Part Image Spend 0
# Processing ZP0575-5918502989404eae0e9e4beab22ff0d7.jpg
# Kmeans Spend 0
# [209 154 149]
# 195.45618820812587 - 178.48248538644728
# 4.0 - 4.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0625-605062c9c686b82ba16b1fed83c2235e.jpg
# Kmeans Spend 0
# [90 71 41]
# 88.94904888888888 - 66.34970666666666
# -14.0 - 2.0
# Transfer Image Spend 25
# Rest Part Image Spend 0
# Processing ZP0546-547032e0c5d6b31b566132e0816b3403.jpg
# Kmeans Spend 0
# [136  99  65]
# 127.18698937908496 - 96.51460375816994
# -11.0 - 4.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0564-5821a60469896c6a1bd981e1535d8e3d.jpg
# Kmeans Spend 0
# [151  48  36]
# 137.27053454078023 - 102.74535291823736
# 2.0 - 19.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0584-5aaa851ce6695fd326e77eb554aef027.jpg
# Kmeans Spend 0
# [120  95  79]
# 119.42278529002907 - 107.33179577909769
# -4.0 - 4.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0617-5fae08dcd382718a1139084c8b999b89.jpg
# Kmeans Spend 0
# [116  98  72]
# 125.78204735660339 - 105.41263523167993
# -4.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0660-65f4282504136e2eaa9a3011dea60e04.jpg
# Kmeans Spend 0
# [124 117  98]
# 127.76544108045591 - 115.82892159606021
# -5.0 - 3.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0581-5a5c7ab362aff28eb8b9bd18811663d4.jpg
# Kmeans Spend 0
# [142 135 116]
# 141.85807081807081 - 129.49406593406593
# -3.0 - 10.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0605-5cf01beee90d2e2eb17263f01c7ba302.jpg
# Kmeans Spend 0
# [99 62 35]
# 99.60607890499195 - 71.79277375201288
# -5.0 - 10.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0560-57ac2a2051ad772f64b7385589548b05.jpg
# Kmeans Spend 0
# [143 112  68]
# 128.91850205428707 - 93.99797938977571
# -2.0 - 16.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0595-5c01f5d337bba599594db6bf4559fe2a.jpg
# Kmeans Spend 0
# [231 185 172]
# 218.83320149765333 - 203.62161841480778
# 2.0 - 6.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0633-617f2d36f528de2cc2cb16e63ee753dd.jpg
# Kmeans Spend 0
# [87 77 60]
# 88.89898382867133 - 76.31370192307692
# -15.0 - -0.0
# Transfer Image Spend 25
# Rest Part Image Spend 0
# Processing ZP0503-4ce5d6c35ac024ab588321fb59c41c3f.jpg
# Kmeans Spend 0
# [152  46  37]
# 136.3765201768933 - 103.99979270315092
# 2.0 - 16.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0638-6218b5876b718fb077ee140276c256b5.jpg
# Kmeans Spend 0
# [105  80  50]
# 101.14893131946424 - 76.06907950983187
# -5.0 - 10.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0619-5fef30e8e951c8a85f27b40dce65a7d9.jpg
# Kmeans Spend 0
# [159  53  41]
# 144.12046296296296 - 111.16712962962963
# 24.0 - 37.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0661-6606ff82a35a238085b1c6178e9160b7.jpg
# Kmeans Spend 0
# [102  62  35]
# 91.72402807680862 - 64.02531113795095
# -5.0 - 10.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0537-52b5706409f0ec761d8322a8f943d657.jpg
# Kmeans Spend 0
# [129  98  75]
# 131.63685114900207 - 108.7113805018977
# -0.0 - 4.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0541-53543a250dc0f1c303fa540aed23c11f.jpg
# Kmeans Spend 0
# [204 155 130]
# 183.07754021838792 - 153.01600400100025
# 6.0 - 24.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0648-6400e7fd81918203b4d5d542f5551462.jpg
# Kmeans Spend 0
# [154  85  62]
# 163.0152505446623 - 135.20337159253947
# 5.0 - 8.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0562-580b754fe6f2888219c9be283457d9d0.jpg
# Kmeans Spend 0
# [142  55  42]
# 141.2400871459695 - 111.24980392156863
# 3.0 - 21.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0697-6c494dfe137cfd3993aa46832c3743bf.jpg
# Kmeans Spend 0
# [96 63 41]
# 96.68841182127895 - 75.24001173651523
# -9.0 - 4.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0644-639a85f0eb5f87c12aac629715c4f05b.jpg
# Kmeans Spend 0
# [210 113  70]
# 187.13236416361417 - 153.59275793650792
# 4.0 - 30.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0588-5b1aa8ad47173b59a8ee8af0bd63ace2.jpg
# Kmeans Spend 0
# [205 142  83]
# 179.8439442964091 - 140.746145793681
# 6.0 - 31.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0666-667c8d566b93a9dc98eb1c6a3b4fa346.jpg
# Kmeans Spend 0
# [149  84  54]
# 151.95905388471178 - 117.95803571428571
# 5.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0630-615f638f772a8ca6dfbcf63d171e6160.jpg
# Kmeans Spend 0
# [208 155 137]
# 197.41668763102726 - 174.83186582809225
# 4.0 - 12.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0641-62ee0e2c4b9a993eab08661dad93e21c.jpg
# Kmeans Spend 0
# [141  47  38]
# 142.44766023508538 - 115.60075681969394
# 24.0 - 16.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0689-69ffef1e489e87dd3daaaf330e929972.jpg
# Kmeans Spend 0
# [178  61  40]
# 165.71849806879746 - 134.87934520569252
# 35.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0629-60f20e577373c5169b2db6db0066aeb7.jpg
# Kmeans Spend 0
# [176 126  98]
# 182.51872067845542 - 156.3544298087333
# -7.0 - -2.0
# Transfer Image Spend 22
# Rest Part Image Spend 0
# Processing ZP0642-6302779f2ead5b69705cad8ab58f79e8.jpg
# Kmeans Spend 0
# [143 123  88]
# 138.02507361059992 - 113.39942951785056
# -1.0 - 30.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0664-6642486c55b2b44afc67ccedcc1eb212.jpg
# Kmeans Spend 0
# [193 152 137]
# 193.06301369863013 - 173.79356579493566
# -12.0 - -1.0
# Transfer Image Spend 27
# Rest Part Image Spend 0
# Processing ZP0598-5c3da8abf88d5e08b6c10232804f36a2.jpg
# Kmeans Spend 0
# [232 195 153]
# 211.75621375310686 - 182.30514705882354
# 2.0 - 2.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0687-69d4460b2c2808dd7f84597284de6842.jpg
# Kmeans Spend 0
# [129 134 119]
# 119.57192405987587 - 112.43318729463307
# -7.0 - 3.0
# Transfer Image Spend 21
# Rest Part Image Spend 0
# Processing ZP0596-5c289f4a488e789d07aa6bd4ccf753b9.jpg
# Kmeans Spend 0
# [128 100  64]
# 132.02196515871375 - 104.4244474282173
# -0.0 - 13.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0583-5a80e24c09d2a8a42f7df26d8fdf2dcc.jpg
# Kmeans Spend 0
# [169  39  27]
# 137.64277356103733 - 99.16731499051234
# 12.0 - 27.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0515-4e9f71d5196f77475a113f09f28ea64f.jpg
# Kmeans Spend 0
# [106  76  48]
# 110.07427721088435 - 84.52725340136054
# -5.0 - 10.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0696-6c256527f054dfc86f16c5fd8f0fb02e.jpg
# Kmeans Spend 0
# [228 162 106]
# 205.44941798941798 - 172.91736961451247
# 2.0 - 11.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0517-4ef5399e7842765e963f86d0da07ba6c.jpg
# Kmeans Spend 0
# [92 46 27]
# 86.66054093567251 - 62.89771929824561
# -12.0 - 4.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0618-5fc2932f0502823e509f692a6d6cf50d.jpg
# Kmeans Spend 0
# [169  42  31]
# 145.98811936936937 - 111.64201858108108
# 23.0 - 39.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0540-5334e064855b068f1c303e0f65b9bb96.jpg
# Kmeans Spend 0
# [181  97  72]
# 187.0699773847922 - 165.1138916694472
# -3.0 - 8.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0532-51d99b69ed4bc295de11fec437153791.jpg
# Kmeans Spend 0
# [145  42  40]
# 137.69042152360768 - 111.29291769692688
# 3.0 - 21.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0616-5f43b4f5773747bfb3a556be461c5454.jpg
# Kmeans Spend 0
# [166  62  48]
# 161.03084992887625 - 131.73790896159318
# 40.0 - 8.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0523-5050182be87fea41408877e816b4bcfc.jpg
# Kmeans Spend 0
# [212 162 119]
# 206.81427419354839 - 181.15451612903226
# 5.0 - 13.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0682-68e45dc279d13cc5a0d06b57b27dbbf7.jpg
# Kmeans Spend 0
# [154 132 106]
# 150.40374100221484 - 131.09291943521595
# -5.0 - -2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0579-5a5b36d11975df5f078ae9ce4196bda4.jpg
# Kmeans Spend 0
# [196 132  98]
# 182.685691501481 - 150.57177033492823
# 6.0 - 31.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0602-5c7b17cd92ac3b041fbc43344e2ff661.jpg
# Kmeans Spend 0
# [178 110  77]
# 155.72490726020138 - 124.31530206677266
# 5.0 - -1.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0673-6791f5bd1914f2d9e99f9e96c457bf22.jpg
# Kmeans Spend 0
# [180  60  34]
# 159.7972119145522 - 123.30433256443686
# 35.0 - 8.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0620-5ff944bb4c77eb7490871992108dc675.jpg
# Kmeans Spend 0
# [117  97  74]
# 129.9721739130435 - 112.6952536231884
# -0.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0520-4ff348e8e0c42b6f535520ec3c2b0907.jpg
# Kmeans Spend 0
# [138 104  84]
# 128.20973319715458 - 109.20072031392786
# 5.0 - 3.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0684-6953f6ffb9914f0333d3d20f9e4f6fe9.jpg
# Kmeans Spend 0
# [163  32  23]
# 129.06047402737863 - 90.93084268100492
# 7.0 - 16.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0649-64247a7b82e9bc2395a25690cbc718d3.jpg
# Kmeans Spend 0
# [165  66  50]
# 147.66252587991718 - 114.08598047914818
# 40.0 - 50.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0522-5048aadaebdb53d559dcd39744ebd447.jpg
# Kmeans Spend 0
# [212 135 132]
# 182.78405112044817 - 159.3824579831933
# 7.0 - 20.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0582-5a72ee32cb84f77d748a52ddcc8964fc.jpg
# Kmeans Spend 0
# [156 128 117]
# 150.83345422308187 - 138.1619922630561
# -4.0 - -2.0
# Transfer Image Spend 19
# Rest Part Image Spend 0
# Processing ZP0623-603fed3a4ea3ef031b31ee3d34fa7df3.jpg
# Kmeans Spend 0
# [136  99  76]
# 122.56227628022499 - 100.42614507999123
# -4.0 - 3.0
# Transfer Image Spend 17
# Rest Part Image Spend 0
# Processing ZP0518-4f3aa14d3b14715fe08288fef1b6f0c8.jpg
# Kmeans Spend 0
# [154 126  88]
# 148.35045933317494 - 115.81777144214777
# -5.0 - -2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0587-5b0749dd68501124e370a0fde0fc619c.jpg
# Kmeans Spend 0
# [179  59  32]
# 148.01571304146893 - 106.6265664160401
# 24.0 - 29.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0574-5901dc4e4defad7f502f07eec1208315.jpg
# Kmeans Spend 0
# [223 163 125]
# 208.29954680418817 - 183.1530707923113
# 2.0 - 9.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0565-5836e75a30ecdc833d890ee7a948ab57.jpg
# Kmeans Spend 0
# [137  60  49]
# 155.11014066378598 - 131.82302105359935
# 30.0 - 9.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0535-527d9ba2cb71b006ca55fe3194cef6ed.jpg
# Kmeans Spend 0
# [152  46  36]
# 132.7441579583049 - 99.13143937404821
# 3.0 - 16.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0507-4d4478756907c521bd5bf6bcfedbaa5c.jpg
# Kmeans Spend 0
# [139  47  47]
# 153.5658457183298 - 134.68845010615712
# 29.0 - 8.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0511-4d5cc1e85da1e0cbbcbb23b81d770d1b.jpg
# Kmeans Spend 0
# [205 148 114]
# 204.88489326765188 - 182.25275414240932
# 4.0 - 14.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0603-5cc2507a7df0cb9df176dac5e3ebb02b.jpg
# Kmeans Spend 0
# [167  60  40]
# 157.28654736467237 - 123.57848112535612
# 35.0 - 8.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0608-5d47ccc4acec6b9bbfe5565d7785b5a8.jpg
# Kmeans Spend 0
# [124 132 103]
# 129.49557522123894 - 113.70442477876107
# -5.0 - 3.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0538-52f1e7a0f81d79565aefddfbf50cda1e.jpg
# Kmeans Spend 0
# [153  34  25]
# 140.1216744913928 - 107.54301898346601
# 2.0 - 19.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0691-6a492d4090a5c9d2d0c8d5e205208b7c.jpg
# Kmeans Spend 0
# [100  47  18]
# 83.13366366366367 - 53.38882882882883
# -5.0 - 10.0
# Transfer Image Spend 16
# Rest Part Image Spend 0
# Processing ZP0539-531c994fbb4bfee57f61cf33fef07a9d.jpg
# Kmeans Spend 0
# [92 54 35]
# 84.74166129675658 - 66.27598269354691
# -11.0 - 4.0
# Transfer Image Spend 20
# Rest Part Image Spend 0
# Processing ZP0688-69d558abf9298a91e1dc795a71d254c8.jpg
# Kmeans Spend 0
# [178  56  37]
# 164.83223091608184 - 132.563725094781
# 34.0 - 8.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0610-5dfb7559ae1061d527aa81aec6606b7a.jpg
# Kmeans Spend 0
# [207 121  78]
# 179.72727419929402 - 142.80389585154958
# 6.0 - 31.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0614-5f1f4726f98cc85f88d2e63c93f29699.jpg
# Kmeans Spend 0
# [138 122 105]
# 158.56766917293234 - 146.67097744360902
# -2.0 - 1.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0519-4f8f1862a0dc035c0cd3557850c21b20.jpg
# Kmeans Spend 0
# [81 72 62]
# 87.65665588334701 - 81.2003766114625
# -15.0 - -2.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0506-4d0dc47adbf1988026b6e1194a09718e.jpg
# Kmeans Spend 0
# [184 108  75]
# 159.33744599349694 - 122.17322168277582
# 5.0 - -1.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0685-69689eae671d7ed04768583c3a93dc5d.jpg
# Kmeans Spend 0
# [120 101  72]
# 121.14278937381404 - 98.9023448088913
# -4.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0547-54b5fc68f72d66917e622e07b758ddb8.jpg
# Kmeans Spend 0
# [216 171 162]
# 209.2829867615836 - 193.92600224803297
# 6.0 - 4.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0534-52108c763b4418f1ee9cb7568edae2a8.jpg
# Kmeans Spend 0
# [131 115  95]
# 135.78389808385108 - 121.32903461598706
# -5.0 - 6.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0589-5b22c7055f3e48127c650d7d76f3c3d0.jpg
# Kmeans Spend 0
# [154 108  85]
# 145.22928672045077 - 121.5758739915482
# 5.0 - 11.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0657-653a2f6798a5e4fd50aa8a96bf71cdf3.jpg
# Kmeans Spend 0
# [204 135  97]
# 184.39547601292568 - 151.2752143922446
# 4.0 - 33.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0672-67791acf2250b48183e37f56b9ca06de.jpg
# Kmeans Spend 0
# [168 159 135]
# 187.56606274856387 - 171.9030932390632
# -15.0 - -2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0530-51c622bab4f76b4a3b045ca0d60259da.jpg
# Kmeans Spend 0
# [203 118  70]
# 157.99104340773653 - 107.47916005500899
# 6.0 - 36.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0556-575b75e68b461c22a31dbb5ddb998ef3.jpg
# Kmeans Spend 0
# [143  56  45]
# 145.04677402125728 - 118.53284730011217
# 24.0 - 18.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0514-4e94f3bad7d822a603d2fb6f20710a8a.jpg
# Kmeans Spend 0
# [179 120  83]
# 171.1251293947444 - 142.9248699816665
# 2.0 - -1.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0663-663b49ae69d5aae5e1029ef3402720a8.jpg
# Kmeans Spend 0
# [143  42  42]
# 140.62535698297287 - 117.44319918492104
# 13.0 - 16.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0675-67c9e6b581edcb3514b2e176737210d6.jpg
# Kmeans Spend 0
# [168  45  31]
# 145.33329003391788 - 109.41450530417839
# 23.0 - 37.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0555-57448c83c00bce7fba15ff2275f43006.jpg
# Kmeans Spend 0
# [106  74  50]
# 102.41186262801723 - 78.93480620996634
# -5.0 - 10.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0640-62c09a58bb6bf3c1a9b6a6c9b25003ea.jpg
# Kmeans Spend 0
# [155  78  55]
# 161.1734373262151 - 130.13855522188857
# 5.0 - 8.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0622-60299a0f8d7e97a5b3859bd2b81c31c6.jpg
# Kmeans Spend 0
# [134  86  69]
# 120.77187366623987 - 96.2237269772481
# -11.0 - 5.0
# Transfer Image Spend 25
# Rest Part Image Spend 0
# Processing ZP0659-65b885dc6339269d80e0e4408953cf3c.jpg
# Kmeans Spend 0
# [197 114  76]
# 169.03629988967978 - 132.48769098245455
# 6.0 - 31.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0698-6c65c5928dafcc8ce87d3330926b65c4.jpg
# Kmeans Spend 0
# [210 200 190]
# 223.23327652739417 - 214.73126873126873
# 5.0 - 8.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0631-6167c265bf1ab67240bf4f0317aff18c.jpg
# Kmeans Spend 0
# [219 150 101]
# 187.38022720509724 - 147.62164574909414
# 2.0 - 25.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0553-5719fbe2ed0f39847b119db3d3798c5a.jpg
# Kmeans Spend 0
# [130  99  80]
# 123.72843297843298 - 106.9321253071253
# -4.0 - 3.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0597-5c34365f779669d0997883498ba15b5e.jpg
# Kmeans Spend 0
# [158  72  75]
# 168.22558793456034 - 151.59070381731425
# 20.0 - 4.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0569-58af3b00b059d44dcc437500f46be7b8.jpg
# Kmeans Spend 0
# [190 123  99]
# 162.71802641802643 - 127.61526806526807
# -3.0 - -1.0
# Transfer Image Spend 24
# Rest Part Image Spend 0
# Processing ZP0637-62080794dee518d019bc75fb271f409e.jpg
# Kmeans Spend 0
# [211 167 158]
# 205.1499625678458 - 189.59334643458732
# 5.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0694-6b8467a4503ddd08487c4ab79a1b2f72.jpg
# Kmeans Spend 0
# [144  53  38]
# 142.80992562542258 - 111.26032454361055
# 14.0 - 21.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0624-604015324ab079c1922297a903e8a9d4.jpg
# Kmeans Spend 0
# [216 175 172]
# 214.49200501159862 - 203.51851438353614
# 6.0 - 8.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0671-676c7de31019c480c1d595ee3defb6b8.jpg
# Kmeans Spend 0
# [114  96  74]
# 114.27225162019145 - 96.39437540876389
# -11.0 - 5.0
# Transfer Image Spend 21
# Rest Part Image Spend 0
# Processing ZP0528-515809e7ccb670645ac7f020da086cac.jpg
# Kmeans Spend 0
# [146  80  60]
# 165.36086353733413 - 140.4691027926322
# 5.0 - 8.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0676-67d3353901e976832dca56d608d9bc57.jpg
# Kmeans Spend 0
# [226 184 136]
# 218.4056307542223 - 195.45134443021766
# 2.0 - 10.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0508-4d52a5cd93a8987ecd4bebdc03404b51.jpg
# Kmeans Spend 0
# [149  92  72]
# 172.60245298219297 - 149.6328860738395
# 5.0 - 8.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0542-53afe438243826b8e9777f771f7393a4.jpg
# Kmeans Spend 0
# [94 63 33]
# 88.75532462918554 - 60.97202238209432
# -14.0 - 4.0
# Transfer Image Spend 29
# Rest Part Image Spend 0
# Processing ZP0504-4ce9dc13a531d1be86f6a4c711d6bf73.jpg
# Kmeans Spend 0
# [201 148 150]
# 210.56590203106333 - 203.8552688172043
# 4.0 - 5.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0601-5c7ac40df6cc0c7757a8831c502b8f88.jpg
# Kmeans Spend 0
# [184  98  74]
# 183.66729151889757 - 160.08693889958457
# -1.0 - 5.0
# Transfer Image Spend 20
# Rest Part Image Spend 0
# Processing ZP0674-67b252af35c99ef1509de244e5267285.jpg
# Kmeans Spend 0
# [154  53  42]
# 146.24205227710522 - 115.87328637111402
# 24.0 - 18.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0593-5b80ac7d3c8a70cec5057b0f10be324b.jpg
# Kmeans Spend 0
# [182 119 101]
# 165.17555272108842 - 136.82929421768708
# -3.0 - -1.0
# Transfer Image Spend 21
# Rest Part Image Spend 0
# Processing ZP0549-5509d04b3b81a0d84fcfb7f95500f925.jpg
# Kmeans Spend 0
# [234 180 135]
# 206.34335163448188 - 172.4065694812571
# 2.0 - 10.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0681-68dee6ac67ce0d6c85c33c598aa2198e.jpg
# Kmeans Spend 0
# [224 161 151]
# 211.3083372027034 - 196.63488624052005
# 2.0 - 2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0505-4cf2d97201838617c997cf92c425468a.jpg
# Kmeans Spend 0
# [174 110  90]
# 186.5997464602639 - 163.6299748245755
# -6.0 - -2.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0512-4d7f0f2d801d9c15707a91bea74925de.jpg
# Kmeans Spend 0
# [209 156 156]
# 208.49609379746067 - 197.16136322216147
# 5.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0613-5f091581bcd5c9aac1b40c6201227fe4.jpg
# Kmeans Spend 0
# [215 169 163]
# 207.0583258460617 - 192.6035040431267
# 6.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0527-514888213ea98006bfbf509b1e88b696.jpg
# Kmeans Spend 0
# [131  49  40]
# 132.7573626306273 - 105.944837730992
# 1.0 - 15.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0643-6383cabddf47a0d609934334c1f43f26.jpg
# Kmeans Spend 0
# [133 110  75]
# 132.1222711062227 - 103.73252674732527
# -0.0 - 13.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0551-564f0791a7a8f501b6db5fa6a75a7d74.jpg
# Kmeans Spend 0
# [156 123  89]
# 146.72742825607065 - 116.49862030905078
# -4.0 - 11.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0590-5b2537c3ba53e2cac6927c2737da904f.jpg
# Kmeans Spend 0
# [96 57 28]
# 78.1156462585034 - 47.704021959661056
# -9.0 - 4.0
# Transfer Image Spend 19
# Rest Part Image Spend 0
# Processing ZP0615-5f383b1a19d4dbf7dd09578925f029f6.jpg
# Kmeans Spend 0
# [128 114 100]
# 145.07227491935743 - 133.48500526971353
# -5.0 - 7.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0695-6c1530d25022ac51550965c024ef48e0.jpg
# Kmeans Spend 0
# [73 52 35]
# 83.01140637140637 - 67.14680652680653
# -11.0 - 3.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0609-5d996b562ff6600309fddd88a326d8cb.jpg
# Kmeans Spend 0
# [221 186 165]
# 214.28841510903428 - 195.316238317757
# 2.0 - 4.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0607-5d4177c1352f88182787e5fdf64500c4.jpg
# Kmeans Spend 0
# [227 156 147]
# 208.9715441158394 - 190.5340733092411
# 2.0 - 2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0513-4dc4a61c871180c876297372e02fcf90.jpg
# Kmeans Spend 0
# [138  75  56]
# 109.60053290700773 - 79.5168132160938
# -6.0 - 5.0
# Transfer Image Spend 23
# Rest Part Image Spend 0
# Processing ZP0516-4ea701f6635d1fbab9e45b2e1f97ab60.jpg
# Kmeans Spend 0
# [132  61  50]
# 148.33729767074615 - 124.86878207658903
# 22.0 - 9.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0670-67472c01da90a8d2da9a2989d0900c72.jpg
# Kmeans Spend 0
# [82 37 19]
# 66.8301703163017 - 41.84530954311976
# -11.0 - 3.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0646-63c04faa546d34e4b452d82969b34665.jpg
# Kmeans Spend 0
# [94 75 61]
# 96.20180167055167 - 83.05893065268066
# -15.0 - -2.0
# Transfer Image Spend 22
# Rest Part Image Spend 0
# Processing ZP0525-5137682a55e73afc3ce31f2564f9dada.jpg
# Kmeans Spend 0
# [163  52  31]
# 139.91038433111603 - 99.65819546307351
# 12.0 - 27.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0654-650da449d46117ef7a3c50b6e72f83d4.jpg
# Kmeans Spend 0
# [236 238 237]
# 198.16059874456784 - 197.79922742636407
# 2.0 - 4.0
# Transfer Image Spend 13
# Rest Part Image Spend 0
# Processing ZP0566-5844a5681e5bee62cd95b1e36cd92d94.jpg
# Kmeans Spend 0
# [115  95  64]
# 110.39353995198903 - 86.59908693415638
# -11.0 - 5.0
# Transfer Image Spend 21
# Rest Part Image Spend 0
# Processing ZP0677-682439bbe935502b313cd6fcb8215e86.jpg
# Kmeans Spend 0
# [116  93  64]
# 108.68053986562816 - 83.93614364706582
# -11.0 - 5.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0621-600e29dc1b895002a4672c9aa6d3bf14.jpg
# Kmeans Spend 0
# [124 109  97]
# 129.21379547014413 - 117.69080301990391
# -3.0 - 3.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0533-51e0348f1ba2b5e8f3ecce091413ac45.jpg
# Kmeans Spend 0
# [160  47  38]
# 144.30277056957877 - 112.28902256821577
# 34.0 - 39.0
# Transfer Image Spend 14
# Rest Part Image Spend 0
# Processing ZP0679-686634526c8a6877d875a6044719a4ca.jpg
# Kmeans Spend 0
# [222 143 111]
# 191.69027372853904 - 158.82009232264335
# 2.0 - 24.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0529-51bbd7e8e13f23ec4285ac6b7b2e4548.jpg
# Kmeans Spend 0
# [105  87  87]
# 123.0660546061243 - 118.10115590951828
# -5.0 - 4.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0683-68e98fbb09729755ba2e06b5c907e8b2.jpg
# Kmeans Spend 0
# [153 136 110]
# 156.70858484238767 - 136.8306338028169
# -4.0 - -2.0
# Transfer Image Spend 15
# Rest Part Image Spend 0
# Processing ZP0580-5a5b789ba6ab971f7ad0dc0445563ece.jpg
# Kmeans Spend 0
# [94 81 57]
# 100.03244565217392 - 82.3821195652174
# -15.0 - -2.0
# Transfer Image Spend 18
# Rest Part Image Spend 0
# Processing ZP0680-68d273a7384d6eaaa28de776931c4600.jpg
# Kmeans Spend 0
# [81 56 29]
# 81.02115949324607 - 56.88361439718097
# -11.0 - 3.0
# Transfer Image Spend 20
# Rest Part Image Spend 0

# %%
tmp_a = cv2.imread("image/origin/ZP0505-4cf2d97201838617c997cf92c425468a.jpg", cv2.IMREAD_COLOR)
hsv = cv2.cvtColor(tmp_a, cv2.COLOR_BGR2HSV)
mean = np.mean(hsv)
mean_g,mean_s,mean_v = np.mean(hsv[:,:,0]),np.mean(hsv[:,:,1]),np.mean(hsv[:,:,2])
print("{} -- {} -- {} -- {}".format(mean, mean_g,mean_s,mean_v))
# Out:
# 99.04099158813821 -- 40.334384682957996 -- 11.437388196773679 -- 245.35120188468295

# %%
a = [57.264625059894584, 20.940041526912633, 241.17082494809137]
b = [66.36295360166108, 22.985279508065805,147.1553314167066]
(sum(a)-sum(b))/3
# Out:
# 27.623975669488363

# %%
lv_filenames = glob.glob(os.path.join("image/origin", '*.jpg'))
hsv_mean_lst = []
blue_color_lst = []
file_name_lst = []
for filename in lv_filenames:
    tmp_a = cv2.imread(filename, cv2.IMREAD_COLOR)
    hsv = cv2.cvtColor(tmp_a, cv2.COLOR_BGR2HSV)
    mean = np.mean(hsv)
    mean_g,mean_s,mean_v = np.mean(hsv[:,:,0]),np.mean(hsv[:,:,1]),np.mean(hsv[:,:,2])
    hsv_mean_lst.append([mean, mean_v])
    qrcode_file = "{}/{}_qrcode.jpg".format(qrcode_path, os.path.splitext(os.path.basename(filename))[0])
    if not os.path.exists(qrcode_file):
        print("Missing qrcode jpg for image {}".format(source_file))
        continue
    file_name_lst.append(os.path.basename(filename))
    img = cv2.imread(qrcode_file,cv2.IMREAD_COLOR)
    blue_color = get_blue_color_center_by_kmeans(img, 2)
    blue_color_lst.append(blue_color)

# %%
features_lst = []
for idx in range(len(file_name_lst)):
    features_lst.append([hsv_mean_lst[idx][0], hsv_mean_lst[idx][1], blue_color_lst[idx][0], blue_color_lst[idx][1], blue_color_lst[idx][2]])
print(features_lst)
# Out:
# [[103.18516397806528, 241.15553905126976, 139, 48, 40], [119.63441995421391, 243.20553026673056, 204, 135, 113], [96.3146237289038, 251.4923171218655, 216, 194, 168], [66.56835090241175, 122.32527112282384, 72, 43, 26], [98.8236630197519, 198.42252635361763, 143, 123, 88], [104.91412114678167, 241.13959950487143, 165, 66, 50], [97.71518620561146, 207.9527212106692, 154, 127, 89], [94.20602273332268, 220.49078461907044, 168, 159, 135], [66.48773172549646, 133.13002954799552, 95, 75, 61]]

# %%
print(file_name_lst)
# Out:
# ['ZP0658-65b14941487532fe9cb0a66e0e8bb2ec.jpg', 'ZP0571-58b457ff568d5f390496cba800026355.jpg', 'ZP0650-643c893ebc1d1621d139be905e8c4681.jpg', 'ZP0686-69b2d3d96e9533c2756dfb59b982bf09.jpg', 'ZP0642-6302779f2ead5b69705cad8ab58f79e8.jpg', 'ZP0649-64247a7b82e9bc2395a25690cbc718d3.jpg', 'ZP0518-4f3aa14d3b14715fe08288fef1b6f0c8.jpg', 'ZP0672-67791acf2250b48183e37f56b9ca06de.jpg', 'ZP0646-63c04faa546d34e4b452d82969b34665.jpg']

# %%
for idx in [35, 51, 182, 63]:
    print(file_name_lst[idx])
# Out:
# ZP0571-58b457ff568d5f390496cba800026355.jpg
# ZP0650-643c893ebc1d1621d139be905e8c4681.jpg
# ZP0646-63c04faa546d34e4b452d82969b34665.jpg
# ZP0686-69b2d3d96e9533c2756dfb59b982bf09.jpg

# %%
print(np.mean(np.array(hsv_mean_lst)[:, 0]))
print(np.mean(np.array(hsv_mean_lst)[:, 1]))
print(np.median(np.array(hsv_mean_lst)[:, 0]))
print(np.median(np.array(hsv_mean_lst)[:, 1]))
# Out:
# 94.34290894143147
# 210.9805115347504
# 98.88797948943193
# 241.1475692780706

# %%
mean_lst = abs(np.array(hsv_mean_lst)[:, 0] - 94.34290894143147)
print(np.where(mean_lst==np.min(mean_lst)))
mean_lst = abs(np.array(hsv_mean_lst)[:, 1] - 210.9805115347504)
print(np.where(mean_lst==np.min(mean_lst)))
mean_lst = abs(np.array(hsv_mean_lst)[:, 0] - 98.88797948943193)
print(np.where(mean_lst==np.min(mean_lst)))
mean_lst = abs(np.array(hsv_mean_lst)[:, 1] - 241.1475692780706)
print(np.where(mean_lst==np.min(mean_lst)))
print(np.min(mean_lst))
# Out:
# (array([139]),)
# (array([117]),)
# (array([92]),)
# (array([ 18, 113]),)
# 0.007969773199164365

# %%
for idx in [139, 117, 92, 18, 113]:
    print(file_name_lst[idx])
# Out:
# ZP0672-67791acf2250b48183e37f56b9ca06de.jpg
# ZP0518-4f3aa14d3b14715fe08288fef1b6f0c8.jpg
# ZP0642-6302779f2ead5b69705cad8ab58f79e8.jpg
# ZP0658-65b14941487532fe9cb0a66e0e8bb2ec.jpg
# ZP0649-64247a7b82e9bc2395a25690cbc718d3.jpg

# %%
from sklearn.multioutput import MultiOutputRegressor
from sklearn.ensemble import GradientBoostingRegressor
X_train = np.array([
    [103.18516397806528, 241.15553905126976, 139, 48, 40],
    [119.63441995421391, 243.20553026673056, 204, 135, 113], 
    [96.3146237289038, 251.4923171218655, 216, 194, 168],
    [66.56835090241175, 122.32527112282384, 72, 43, 26],
    [98.8236630197519, 198.42252635361763, 143, 123, 88], 
    [104.91412114678167, 241.13959950487143, 165, 66, 50], 
    [97.71518620561146, 207.9527212106692, 154, 127, 89], 
    [94.20602273332268, 220.49078461907044, 168, 159, 135], 
    [66.48773172549646, 133.13002954799552, 95, 75, 61]
])

y_train = np.array([
    [4, 20],
    [4, 33],
    [40, 50],
    [-11, 3],
    [-1, 30],
    [40, 50],
    [-5, -2],
    [-15, -2],
    [-15, -2],
])
X_train2 = np.array([
    [103.18516397806528, 241.15553905126976, 139, 48, 40, 4],
    [119.63441995421391, 243.20553026673056, 204, 135, 113, 4], 
    [96.3146237289038, 251.4923171218655, 216, 194, 168, 40],
    [66.56835090241175, 122.32527112282384, 72, 43, 26, -11],
    [98.8236630197519, 198.42252635361763, 143, 123, 88, -1], 
    [104.91412114678167, 241.13959950487143, 165, 66, 50, 40], 
    [97.71518620561146, 207.9527212106692, 154, 127, 89, -5], 
    [94.20602273332268, 220.49078461907044, 168, 159, 135, -15], 
    [66.48773172549646, 133.13002954799552, 95, 75, 61, -15]
])
max_depth = 20
model_g = GradientBoostingRegressor(n_estimators=50, loss='huber', max_depth=max_depth)
model_g.fit(X_train, y_train[:,0])
model_r = GradientBoostingRegressor(n_estimators=50, loss='huber', max_depth=max_depth)
model_r.fit(X_train, y_train[:,1])

X_test = np.array([[103.18516397806528, 241.15553905126976, 138, 47, 40]])
# Predict on new data
y_multirf = model_g.predict(X_test)
print(y_multirf)
#X_test2 = np.append(X_test2[0], y_multirf)
y_multirf = model_r.predict(X_test)
print(y_multirf)
# Out:
# [3.97423112]
# [20.]

# %%
X_test = np.array([[103.18516397806528, 241.15553905126976, 138, 47, 40]])
model_g, model_r = init_predict_mode()
y_multirf = model_g.predict(X_test)
print(y_multirf)
#X_test2 = np.append(X_test2[0], y_multirf)
y_multirf = model_r.predict(X_test)
print(y_multirf)
# Out:
# [3.97423112]
# [20.]
